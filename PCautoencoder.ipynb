# %% [markdown]
# <a href="https://colab.research.google.com/github/javmencia/HIVElab/blob/main/PCautoencoder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, callbacks
from tensorflow.keras.optimizers import Adam
import warnings
warnings.filterwarnings('ignore')

class AdvancedMissingDataHandler:
    def __init__(self):
        self.scaler = StandardScaler()
        self.label_encoders = {}
        self.feature_stats = {}
        self.missing_mask = None
        self.numeric_cols = None
        self.categorical_cols = None

    def analyze_data_types(self, df):
        """Analyze data types and identify numeric vs categorical columns"""
        numeric_cols = []
        categorical_cols = []

        for col in df.columns:
            if pd.api.types.is_numeric_dtype(df[col]):
                # Check if it's actually categorical (limited unique values)
                unique_ratio = df[col].nunique() / len(df[col])
                if unique_ratio < 0.05 and df[col].nunique() < 20:
                    categorical_cols.append(col)
                else:
                    numeric_cols.append(col)
            else:
                categorical_cols.append(col)

        print(f"Numeric columns: {len(numeric_cols)}")
        print(f"Categorical columns: {len(categorical_cols)}")

        return numeric_cols, categorical_cols

    def encode_categorical(self, df, categorical_cols):
        """Encode categorical variables"""
        df_encoded = df.copy()

        for col in categorical_cols:
            if col in df.columns:
                # Fill missing categorical values with a special value
                df_encoded[col] = df[col].fillna('MISSING_CAT')

                # Explicitly convert to string to prevent TypeError with mixed types
                df_encoded[col] = df_encoded[col].astype(str)

                # Create or use existing label encoder
                if col not in self.label_encoders:
                    self.label_encoders[col] = LabelEncoder()
                    self.label_encoders[col].fit(df_encoded[col])

                # Transform the column
                df_encoded[col] = self.label_encoders[col].transform(df_encoded[col])

        return df_encoded

    def create_missing_mask(self, df):
        """Create mask indicating missing values"""
        return df.isnull().astype(int).values

    def create_input_with_missing_indicators(self, df, numeric_cols, categorical_cols):
        """Create input with missing indicators and placeholder values"""
        df_processed = df.copy()

        # Store statistics for numeric columns
        for col in numeric_cols:
            if col in df.columns:
                self.feature_stats[col] = {
                    'mean': df[col].mean(),
                    'median': df[col].median(),
                    'std': df[col].std(),
                    'min': df[col].min(),
                    'max': df[col].max()
                }

        # Process numeric columns
        for col in numeric_cols:
            if col in df.columns:
                # Convert infinite values to NaN before filling with placeholder
                df_processed[col] = df_processed[col].replace([np.inf, -np.inf], np.nan)

                # Create missing indicator
                indicator_name = f"{col}_missing"
                df_processed[indicator_name] = df[col].isnull().astype(int)

                # Fill with placeholder (scaled zero)
                placeholder = 0  # Will be scaled later
                df_processed[col] = df_processed[col].fillna(placeholder)

        # Process categorical columns
        df_processed = self.encode_categorical(df_processed, categorical_cols)

        # Create missing indicators for categorical columns
        for col in categorical_cols:
            if col in df.columns:
                # Create missing indicator (after encoding)
                indicator_name = f"{col}_missing"
                df_processed[indicator_name] = (df[col].isnull()).astype(int)

        return df_processed

    def prepare_for_autoencoder(self, df, feature_cols):
        """Prepare data for autoencoder imputation"""
        # Identify numeric and categorical columns
        self.numeric_cols, self.categorical_cols = self.analyze_data_types(df[feature_cols])

        print(f"\nPreparing {len(feature_cols)} features for autoencoder imputation:")
        print(f"- Numeric features: {len(self.numeric_cols)}")
        print(f"- Categorical features: {len(self.categorical_cols)}")

        # Create input with missing indicators
        df_processed = self.create_input_with_missing_indicators(
            df, self.numeric_cols, self.categorical_cols
        )

        # Get all columns including missing indicators
        all_columns = list(feature_cols)
        for col in feature_cols:
            if col in df_processed.columns and f"{col}_missing" not in all_columns:
                all_columns.append(f"{col}_missing")

        # Ensure all_columns has only unique values and correct order (optional, but good practice)
        # It's important that all_columns here matches the order of columns in X
        # For simplicity, we'll rely on df_processed column order for X and align mask to it
        # Let's ensure df_processed has all_columns in the right order for X creation
        # The next line was already implicitly sorting them, let's make it explicit
        all_columns = [col for col in df_processed.columns if col in set(all_columns)]

        # Scale numeric features (including those with placeholders)
        numeric_features_to_scale = [col for col in self.numeric_cols if col in df_processed.columns]
        if numeric_features_to_scale:
            df_processed[numeric_features_to_scale] = self.scaler.fit_transform(
                df_processed[numeric_features_to_scale]
            )

        # Create final feature matrix
        X = df_processed[all_columns].values

        # --- Start of modifications for the missing mask ---
        # Create a new DataFrame for the missing mask, initialized with zeros
        full_missing_mask_df = pd.DataFrame(0, index=df_processed.index, columns=all_columns, dtype=np.float32)

        # Populate the mask for original features
        for original_col in feature_cols:
            if original_col in full_missing_mask_df.columns:
                full_missing_mask_df[original_col] = df[original_col].isnull().astype(np.float32)

        # Assign the values of the full_missing_mask_df to self.missing_mask
        self.missing_mask = full_missing_mask_df.values
        # --- End of modifications ---

        print(f"Final feature matrix shape: {X.shape}")
        print(f"Missing mask shape: {self.missing_mask.shape}")

        return X, all_columns


class DenoisingAutoencoderImputer:
    def __init__(self, input_dim, encoding_dim=32, noise_factor=0.1):
        self.input_dim = input_dim
        self.encoding_dim = encoding_dim
        self.noise_factor = noise_factor
        self.autoencoder = None
        self.history = None

    def build_autoencoder(self):
        """Build a denoising autoencoder for imputation"""
        # Input layer
        input_layer = layers.Input(shape=(self.input_dim,))

        # Add noise for denoising (during training only)
        noisy_input = layers.GaussianNoise(self.noise_factor)(input_layer)

        # Encoder
        encoded = layers.Dense(128, activation='relu')(noisy_input)
        encoded = layers.BatchNormalization()(encoded)
        encoded = layers.Dense(64, activation='relu')(encoded)
        encoded = layers.BatchNormalization()(encoded)
        encoded = layers.Dense(self.encoding_dim, activation='relu')(encoded)

        # Decoder
        decoded = layers.Dense(64, activation='relu')(encoded)
        decoded = layers.BatchNormalization()(decoded)
        decoded = layers.Dense(128, activation='relu')(decoded)
        decoded = layers.BatchNormalization()(decoded)
        decoded = layers.Dense(self.input_dim, activation='linear')(decoded)

        # Create model
        self.autoencoder = models.Model(inputs=input_layer, outputs=decoded)

        # Compile with custom loss
        self.autoencoder.compile(
            optimizer=Adam(learning_rate=0.001),
            loss='mse',
            metrics=['mae']
        )

        print("Denoising Autoencoder architecture:")
        print(self.autoencoder.summary())

        return self.autoencoder

    def custom_loss(self, y_true, y_pred, missing_mask):
        """Custom loss that only considers non-missing values"""
        # Calculate squared error
        squared_error = tf.square(y_true - y_pred)

        # Mask out missing values (where mask == 1)
        valid_mask = tf.cast(tf.equal(missing_mask, 0), tf.float32)

        # Apply mask
        masked_error = squared_error * valid_mask

        # Calculate mean over non-missing values
        loss = tf.reduce_sum(masked_error) / (tf.reduce_sum(valid_mask) + 1e-8)

        return loss

    def train_with_missing_awareness(self, X_train, missing_mask_train, X_val, missing_mask_val,
                                     epochs=150, batch_size=64):
        """Train autoencoder with missing-aware loss"""

        # Create a custom training loop to handle missing values
        class MissingAwareModel(keras.Model):
            def train_step(self, data):
                # Unpack data: `data` yields `(x_features_batch, (y_true_batch, missing_mask_batch))`
                x_features, (y_true, missing_mask) = data

                with tf.GradientTape() as tape:
                    # Forward pass: model predicts based on x_features
                    y_pred = self(x_features, training=True)

                    # Custom loss only on observed values (using y_true and missing_mask)
                    valid_mask = tf.cast(tf.equal(missing_mask, 0), tf.float32)
                    loss = tf.reduce_sum(tf.square(y_true - y_pred) * valid_mask) / (tf.reduce_sum(valid_mask) + 1e-8)

                # Compute gradients
                trainable_vars = self.trainable_variables
                gradients = tape.gradient(loss, trainable_vars)

                # Update weights
                self.optimizer.apply_gradients(zip(gradients, trainable_vars))

                return {"loss": loss}

            def test_step(self, data):
                # Unpack data for validation: `data` yields `(x_features_batch, (y_true_batch, missing_mask_batch))`
                x_features, (y_true, missing_mask) = data

                # Forward pass
                y_pred = self(x_features, training=False)

                # Custom loss only on observed values
                valid_mask = tf.cast(tf.equal(missing_mask, 0), tf.float32)
                loss = tf.reduce_sum(tf.square(y_true - y_pred) * valid_mask) / (tf.reduce_sum(valid_mask) + 1e-8)

                # Here, we will just return the custom loss to monitor 'val_loss'
                return {"loss": loss}

        # Create model wrapper
        model_wrapper = MissingAwareModel(inputs=self.autoencoder.input,
                                         outputs=self.autoencoder.output)
        # Compile with a dummy loss, as the actual loss calculation is handled in train_step and test_step
        # This satisfies Keras's requirement for a loss argument.
        model_wrapper.compile(optimizer=Adam(learning_rate=0.001), loss=tf.keras.losses.MeanSquaredError())

        # Prepare training data: x is X_train, y is (X_train, missing_mask_train)
        train_data = tf.data.Dataset.from_tensor_slices(
            (X_train, (X_train, missing_mask_train))
        ).batch(batch_size).shuffle(1000)

        val_data = tf.data.Dataset.from_tensor_slices(
            (X_val, (X_val, missing_mask_val))
        ).batch(batch_size)

        # Callbacks
        early_stopping = callbacks.EarlyStopping(
            monitor='val_loss',
            patience=30,
            restore_best_weights=True,
            verbose=1
        )

        reduce_lr = callbacks.ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.5,
            patience=15,
            min_lr=1e-6,
            verbose=1
        )

        print("Training denoising autoencoder with missing-aware loss...")

        # Train model
        history = model_wrapper.fit(
            train_data,
            validation_data=val_data,
            epochs=epochs,
            callbacks=[early_stopping, reduce_lr],
            verbose=1
        )

        self.history = history
        self.model_wrapper = model_wrapper

        # Plot training history
        self.plot_training_history()

        return history

    def plot_training_history(self):
        """Plot training history"""
        if self.history is None:
            return

        fig, axes = plt.subplots(1, 2, figsize=(12, 4))

        # Plot loss
        axes[0].plot(self.history.history['loss'], label='Training Loss')
        if 'val_loss' in self.history.history:
            axes[0].plot(self.history.history['val_loss'], label='Validation Loss')
        axes[0].set_title('Autoencoder Training Loss')
        axes[0].set_xlabel('Epoch')
        axes[0].set_ylabel('Loss')
        axes[0].legend()
        axes[0].grid(True)

        plt.tight_layout()
        plt.show()

    def impute_missing_values(self, X, missing_mask):
        """Impute missing values using trained autoencoder"""
        print("Imputing missing values using trained autoencoder...")

        # Get predictions
        X_imputed = self.autoencoder.predict(X, verbose=0)

        # Convert X to a NumPy array to use the .copy() method and array-like indexing
        X_np = X.numpy() if isinstance(X, tf.Tensor) else X

        # Only replace missing values (where missing_mask == 1)
        X_final = X_np.copy()
        X_final[missing_mask == 1] = X_imputed[missing_mask == 1]

        # Calculate imputation statistics
        n_imputed = np.sum(missing_mask)
        print(f"Imputed {n_imputed} missing values")

        return X_final


class SurvivalDataPreprocessor:
    def __init__(self):
        self.feature_stats = {}
        self.selected_features = []
        self.missing_handler = AdvancedMissingDataHandler()
        self.autoencoder_imputer = None

    def analyze_missing_data(self, df):
        """Comprehensive analysis of missing data patterns"""
        print("=== MISSING DATA ANALYSIS ===")

        total_rows = len(df)
        missing_summary = pd.DataFrame({
            'missing_count': df.isnull().sum(),
            'missing_percentage': (df.isnull().sum() / total_rows) * 100
        }).sort_values('missing_percentage', ascending=False)

        print("Missing data by column:")
        print(missing_summary[missing_summary['missing_count'] > 0])

        plt.figure(figsize=(15, 10))
        missing_cols = missing_summary[missing_summary['missing_count'] > 0].index
        if len(missing_cols) > 0:
            sns.heatmap(df[missing_cols].isnull(), cbar=True, yticklabels=False, cmap='viridis')
            plt.title('Missing Data Pattern')
            plt.tight_layout()
            plt.show()

        return missing_summary

    def handle_missing_survival_data(self, df):
        """Handle missing values in survival outcomes"""
        df_clean = df.copy()

        survival_vars = ['VISDAY', 'os_event']
        for var in survival_vars:
            if var in df.columns:
                missing_count = df[var].isnull().sum()
                if missing_count > 0:
                    print(f"WARNING: {missing_count} missing values in {var}")
                    df_clean = df_clean.dropna(subset=[var])
                    print(f"Removed {missing_count} rows with missing {var}")

        return df_clean

    def select_features(self, df, max_missing_percentage=50):
        """Select features for analysis"""
        candidate_features = [
            'AGE', 'VISDAY', 'cycle_number', 'total_cycles',
            'anytarget', 'anynontarget', 'total_ae_events', 'serious_ae_count',
            'grade3_plus_count', 'any_grade3_plus', 'total_body_systems',
            'treatment_related_count', 'any_treatment_related', 'grade1_count',
            'grade2_count', 'grade3_count', 'grade4_count', 'drug_interrupted',
            'drug_reduced', 'drug_withdrawn', "drug_not_changed", "other_drug_interrupted",
            "other_drug_reduced", "other_drug_withdrawn", "concomitant_treatment_given",
            'cum_any_grade3_plus', 'cum_any_treatment_related', "cum_drug_withdrawn",
            "cum_other_drug_withdrawn", "cum_concomitant_treatment", "ongoing_ae_count",
            "mean_ae_duration", "max_ae_duration", "most_recent_ae_term", "most_recent_ae_severity"
        ]

        # Filter to available columns
        available_features = [col for col in candidate_features if col in df.columns]

        # Remove features with text/categorical data that can't be imputed easily
        text_features = ['most_recent_ae_term']
        features_to_keep = [f for f in available_features if f not in text_features]

        print(f"Selected {len(features_to_keep)} features for modeling")

        self.selected_features = features_to_keep
        return features_to_keep

    def preprocess_for_autoencoder_imputation(self, df):
        """Complete preprocessing pipeline with autoencoder imputation"""
        print("Starting advanced preprocessing with autoencoder imputation...")

        # Step 1: Handle survival data
        df_clean = self.handle_missing_survival_data(df)
        print(f"Data after handling missing survival outcomes: {len(df_clean)} rows")

        # Step 2: Select features
        features = self.select_features(df_clean)

        # Step 3: Analyze missing patterns
        missing_summary = self.analyze_missing_data(df_clean[features])

        # Step 4: Prepare for autoencoder imputation
        X_prepared, all_columns = self.missing_handler.prepare_for_autoencoder(
            df_clean, features
        )

        # Step 5: Get missing mask
        missing_mask = self.missing_handler.missing_mask

        # Step 6: Add survival variables back
        survival_data = df_clean[['VISDAY', 'os_event']].values

        return X_prepared, missing_mask, survival_data, all_columns, features


class AutoencoderLSTM_Survival:
    def __init__(self, input_dim, encoding_dim=32, sequence_length=3, lstm_units=64):
        self.input_dim = input_dim
        self.encoding_dim = encoding_dim
        self.sequence_length = sequence_length
        self.lstm_units = lstm_units
        self.autoencoder = None
        self.encoder = None
        self.lstm_model = None
        self.history_autoencoder = None
        self.history_lstm = None

    def build_lstm_autoencoder(self):
        """Build LSTM-based autoencoder for time series imputation"""
        # Input layer
        input_layer = layers.Input(shape=(self.sequence_length, self.input_dim))

        # Encoder LSTM
        encoded = layers.LSTM(self.encoding_dim * 2, return_sequences=True)(input_layer)
        encoded = layers.LSTM(self.encoding_dim, return_sequences=False)(encoded)

        # Repeat vector for decoder
        repeated = layers.RepeatVector(self.sequence_length)(encoded)

        # Decoder LSTM
        decoded = layers.LSTM(self.encoding_dim, return_sequences=True)(repeated)
        decoded = layers.LSTM(self.encoding_dim * 2, return_sequences=True)(decoded)
        decoded = layers.TimeDistributed(layers.Dense(self.input_dim))(decoded)

        # Create autoencoder
        self.autoencoder = models.Model(inputs=input_layer, outputs=decoded)

        # Create encoder
        self.encoder = models.Model(inputs=input_layer, outputs=encoded)

        # Compile
        self.autoencoder.compile(
            optimizer=Adam(learning_rate=0.001),
            loss='mse',
            metrics=['mae']
        )

        print("LSTM Autoencoder architecture:")
        print(self.autoencoder.summary())

        return self.autoencoder, self.encoder

    def build_survival_lstm(self):
        """Build LSTM model for survival prediction"""
        # Input layer: Expects (sequence_length, encoding_dim) after feature extraction
        input_layer = layers.Input(shape=(self.sequence_length, self.input_dim)) # input_dim here will be the feature_dim = encoding_dim of the AE-LSTM

        # Bidirectional LSTM layer
        lstm_sequence_output = layers.Bidirectional(layers.LSTM(self.lstm_units, return_sequences=True))(input_layer)
        lstm_sequence_output = layers.Dropout(0.3)(lstm_sequence_output)

        # --- Refactored Attention Mechanism ---
        # Calculate attention scores
        attention_scores = layers.TimeDistributed(layers.Dense(1, activation='tanh'))(lstm_sequence_output)
        # Calculate attention weights
        attention_weights = layers.Softmax(axis=1)(attention_scores)
        # Apply attention weights to the LSTM output
        context_vector = layers.Multiply()([lstm_sequence_output, attention_weights])
        # Sum the context vector along the sequence dimension to get a single representation
        sent_representation = layers.Lambda(lambda xin: tf.reduce_sum(xin, axis=1))(context_vector)
        # --- End Refactored Attention Mechanism ---

        # Dense layers
        dense_out = layers.Dense(64, activation='relu')(sent_representation)
        dense_out = layers.BatchNormalization()(dense_out)
        dense_out = layers.Dropout(0.2)(dense_out)
        dense_out = layers.Dense(32, activation='relu')(dense_out)
        dense_out = layers.BatchNormalization()(dense_out)

        # Output layers
        output_survival_time = layers.Dense(1, activation='relu', name='survival_time')(dense_out)
        output_event = layers.Dense(1, activation='sigmoid', name='event')(dense_out)

        # Create model
        self.lstm_model = models.Model(
            inputs=input_layer,
            outputs=[output_survival_time, output_event]
        )

        # Compile
        self.lstm_model.compile(
            optimizer=Adam(learning_rate=0.0005),
            loss={
                'survival_time': 'mse',
                'event': 'binary_crossentropy'
            },
            loss_weights={
                'survival_time': 0.6,
                'event': 0.4
            },
            metrics={
                'survival_time': ['mae', tf.keras.metrics.RootMeanSquaredError()],
                'event': ['accuracy', tf.keras.metrics.AUC()]
            }
        )

        print("Survival LSTM architecture:")
        print(self.lstm_model.summary())

        return self.lstm_model

    def create_sequences(self, X, y, sequence_length):
        """Create sequences for LSTM"""
        sequences = []
        labels = []

        for i in range(len(X) - sequence_length + 1):
            sequences.append(X[i:i+sequence_length])
            # Use the last time point's label
            labels.append(y[i+sequence_length-1])

        return np.array(sequences), np.array(labels)

    def train_lstm_autoencoder(self, X_train_seq, X_val_seq, epochs=100, batch_size=32):
        """Train LSTM autoencoder"""
        early_stopping = callbacks.EarlyStopping(
            monitor='val_loss',
            patience=25,
            restore_best_weights=True
        )

        reduce_lr = callbacks.ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.5,
            patience=10,
            min_lr=1e-6
        )

        print("Training LSTM autoencoder...")
        self.history_autoencoder = self.autoencoder.fit(
            X_train_seq, X_train_seq,
            epochs=epochs,
            batch_size=batch_size,
            validation_data=(X_val_seq, X_val_seq),
            callbacks=[early_stopping, reduce_lr],
            verbose=1
        )

        self.plot_training_history(self.history_autoencoder, "LSTM Autoencoder")

        return self.history_autoencoder

    def train_survival_lstm(self, X_train_encoded_seq, y_train, X_val_encoded_seq, y_val, epochs=150, batch_size=32):
        """Train survival LSTM"""
        early_stopping = callbacks.EarlyStopping(
            monitor='val_loss',
            patience=30,
            restore_best_weights=True
        )

        reduce_lr = callbacks.ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.5,
            patience=15,
            min_lr=1e-6
        )

        # Convert y to dictionary format for multi-output model
        y_train_dict = {
            'survival_time': y_train[:, 0],
            'event': y_train[:, 1]
        }

        y_val_dict = {
            'survival_time': y_val[:, 0],
            'event': y_val[:, 1]
        }

        print("Training Survival LSTM...")
        self.history_lstm = self.lstm_model.fit(
            X_train_encoded_seq,
            y_train_dict,
            epochs=epochs,
            batch_size=batch_size,
            validation_data=(X_val_encoded_seq, y_val_dict),
            callbacks=[early_stopping, reduce_lr],
            verbose=1
        )

        self.plot_training_history(self.history_lstm, "Survival LSTM")

        return self.history_lstm

    def plot_training_history(self, history, model_name):
        """Plot training history"""
        if history is None:
            return

        fig, axes = plt.subplots(1, 2, figsize=(12, 4))

        # Plot loss
        axes[0].plot(history.history['loss'], label='Training Loss')
        if 'val_loss' in history.history:
            axes[0].plot(history.history['val_loss'], label='Validation Loss')
        axes[0].set_title(f'{model_name} Loss')
        axes[0].set_xlabel('Epoch')
        axes[0].set_ylabel('Loss')
        axes[0].legend()
        axes[0].grid(True)

        # Plot additional metrics
        metric_to_plot = None
        for metric in ['mae', 'accuracy', 'root_mean_squared_error']:
            if metric in history.history:
                metric_to_plot = metric
                break

        if metric_to_plot:
            axes[1].plot(history.history[metric_to_plot],
                        label=f'Training {metric_to_plot.upper()}')
            if f'val_{metric_to_plot}' in history.history:
                axes[1].plot(history.history[f'val_{metric_to_plot}'],
                           label=f'Validation {metric_to_plot.upper()}')
            axes[1].set_title(f'{model_name} {metric_to_plot.upper()}')
            axes[1].set_xlabel('Epoch')
            axes[1].set_ylabel(metric_to_plot.upper())
            axes[1].legend()
            axes[1].grid(True)

        plt.tight_layout()
        plt.show()

    def evaluate(self, X_test_seq, y_test):
        """Evaluate the model"""
        if self.lstm_model is None:
            raise ValueError("Model not trained yet.")

        print("Evaluating model...")

        # Convert y_test to dictionary
        y_test_dict = {
            'survival_time': y_test[:, 0],
            'event': y_test[:, 1]
        }

        results = self.lstm_model.evaluate(X_test_seq, y_test_dict, verbose=0)

        print("\nEvaluation Results:")
        for i, metric in enumerate(self.lstm_model.metrics_names):
            print(f"{metric}: {results[i]:.4f}")

        return results

    def predict(self, X_seq):
        """Make predictions"""
        if self.lstm_model is None:
            raise ValueError("Model not trained yet.")

        predictions = self.lstm_model.predict(X_seq, verbose=0)
        return predictions


def train_complete_pipeline():
    """Complete training pipeline with autoencoder imputation"""
    print("Starting Autoencoder Imputation + LSTM Survival Prediction Pipeline")
    print("=" * 70)

    try:
        # Load data
        print("Loading data...")
        pcdata = pd.read_csv('pcdata.csv')

        # Initialize preprocessor
        preprocessor = SurvivalDataPreprocessor()

        # Preprocess with autoencoder imputation
        print("\n" + "=" * 70)
        print("STAGE 1: Autoencoder-based Imputation")
        print("=" * 70)

        X_prepared, missing_mask, survival_data, all_columns, features = \
            preprocessor.preprocess_for_autoencoder_imputation(pcdata)

        # Split data
        X_train, X_test, mask_train, mask_test, y_train, y_test = train_test_split(
            X_prepared, missing_mask, survival_data,
            test_size=0.3, random_state=42
        )

        X_train, X_val, mask_train, mask_val, y_train, y_val = train_test_split(
            X_train, mask_train, y_train,
            test_size=0.2, random_state=42
        )

        print(f"\nData split:")
        print(f"  Training: {X_train.shape}")
        print(f"  Validation: {X_val.shape}")
        print(f"  Test: {X_test.shape}")

        # Initialize and train denoising autoencoder for imputation
        print("\nTraining Denoising Autoencoder for imputation...")
        autoencoder_imputer = DenoisingAutoencoderImputer(
            input_dim=X_train.shape[1],
            encoding_dim=32,
            noise_factor=0.1
        )

        autoencoder_imputer.build_autoencoder()

        # Explicitly cast data to tf.float32 to prevent dtype mismatch errors
        X_train_tf = tf.cast(X_train, tf.float32)
        mask_train_tf = tf.cast(mask_train, tf.float32)
        X_val_tf = tf.cast(X_val, tf.float32)
        mask_val_tf = tf.cast(mask_val, tf.float32)

        autoencoder_imputer.train_with_missing_awareness(
            X_train_tf, mask_train_tf,
            X_val_tf, mask_val_tf,
            epochs=100,
            batch_size=64
        )

        # Impute missing values
        print("\nImputing missing values...")
        # Ensure X is passed as a NumPy array or converted within the method
        X_train_imputed = autoencoder_imputer.impute_missing_values(X_train_tf, mask_train_tf)
        X_val_imputed = autoencoder_imputer.impute_missing_values(X_val_tf, mask_val_tf)
        X_test_imputed = autoencoder_imputer.impute_missing_values(tf.cast(X_test, tf.float32), tf.cast(mask_test, tf.float32))

        preprocessor.autoencoder_imputer = autoencoder_imputer

        print("\n" + "=" * 70)
        print("STAGE 2: LSTM Survival Prediction")
        print("=" * 70)

        # Create sequences for LSTM
        sequence_length = 3

        # For simplicity, create synthetic sequences from the data
        # In real scenario, you would use actual time-series data
        def create_synthetic_sequences(X, y, seq_length):
            n_sequences = len(X) // seq_length
            X_seq = X[:n_sequences * seq_length].reshape(n_sequences, seq_length, -1)
            y_seq = y[:n_sequences * seq_length].reshape(n_sequences, seq_length, -1)
            # Use last time point for prediction
            y_seq = y_seq[:, -1, :]
            return X_seq, y_seq

        X_train_seq, y_train_seq = create_synthetic_sequences(X_train_imputed, y_train, sequence_length)
        X_val_seq, y_val_seq = create_synthetic_sequences(X_val_imputed, y_val, sequence_length)
        X_test_seq, y_test_seq = create_synthetic_sequences(X_test_imputed, y_test, sequence_length)

        print(f"\nSequence shapes:")
        print(f"  Training sequences: {X_train_seq.shape}, labels: {y_train_seq.shape}")
        print(f"  Validation sequences: {X_val_seq.shape}, labels: {y_val_seq.shape}")
        print(f"  Test sequences: {X_test_seq.shape}, labels: {y_test_seq.shape}")

        # Initialize and train LSTM autoencoder for feature extraction
        print("\nTraining LSTM Autoencoder for feature extraction...")
        lstm_ae = AutoencoderLSTM_Survival(
            input_dim=X_train_seq.shape[2],
            encoding_dim=32,
            sequence_length=sequence_length,
            lstm_units=64
        )

        lstm_ae.build_lstm_autoencoder()
        lstm_ae.train_lstm_autoencoder(
            X_train_seq, X_val_seq,
            epochs=80,
            batch_size=32
        )

        # Extract encoded features (output of the encoder is (batch_size, encoding_dim))
        print("\nExtracting encoded features...")
        X_train_encoded = lstm_ae.encoder.predict(X_train_seq, verbose=0)
        X_val_encoded = lstm_ae.encoder.predict(X_val_seq, verbose=0)
        X_test_encoded = lstm_ae.encoder.predict(X_test_seq, verbose=0)

        # Reshape for survival LSTM (add sequence dimension back for sequence_length=1)
        X_train_encoded_seq = X_train_encoded.reshape(-1, 1, X_train_encoded.shape[1])
        X_val_encoded_seq = X_val_encoded.reshape(-1, 1, X_val_encoded.shape[1])
        X_test_encoded_seq = X_test_encoded.reshape(-1, 1, X_test_encoded.shape[1])

        # Initialize and train Survival LSTM with the extracted features
        print("\nTraining Survival LSTM...")
        # Create a new instance for the survival model with sequence_length=1
        lstm_survival_model = AutoencoderLSTM_Survival(
            input_dim=lstm_ae.encoding_dim, # The input features to this model are the encoded features
            encoding_dim=lstm_ae.encoding_dim, # Can reuse or set as needed for internal layers, not directly used as input dim
            sequence_length=1, # Each encoded feature vector is a 'sequence' of length 1
            lstm_units=lstm_ae.lstm_units # Use the same LSTM units
        )
        lstm_survival_model.build_survival_lstm()
        lstm_survival_model.train_survival_lstm(
            X_train_encoded_seq, y_train_seq,
            X_val_encoded_seq, y_val_seq,
            epochs=120,
            batch_size=32
        )

        # Evaluate
        print("\n" + "=" * 70)
        print("MODEL EVALUATION")
        print("=" * 70)

        results = lstm_survival_model.evaluate(X_test_encoded_seq, y_test_seq)

        # Make predictions
        predictions = lstm_survival_model.predict(X_test_encoded_seq)

        # Calculate additional metrics
        from sklearn.metrics import mean_squared_error, mean_absolute_error, accuracy_score, roc_auc_score

        # Survival time metrics
        y_pred_time = predictions[0].flatten()
        y_true_time = y_test_seq[:, 0]

        mse_time = mean_squared_error(y_true_time, y_pred_time)
        mae_time = mean_absolute_error(y_true_time, y_pred_time)
        rmse_time = np.sqrt(mse_time)

        # Event prediction metrics
        y_pred_event = predictions[1].flatten()
        y_pred_event_binary = (y_pred_event > 0.5).astype(int)
        y_true_event = y_test_seq[:, 1]

        event_accuracy = accuracy_score(y_true_event, y_pred_event_binary)
        event_auc = roc_auc_score(y_true_event, y_pred_event)

        print("\nDetailed Performance Metrics:")
        print(f"\nSurvival Time Prediction:")
        print(f"  MSE: {mse_time:.4f}")
        print(f"  MAE: {mae_time:.4f}")
        print(f"  RMSE: {rmse_time:.4f}")

        print(f"\nEvent Prediction:")
        print(f"  Accuracy: {event_accuracy:.4f}")
        print(f"  AUC-ROC: {event_auc:.4f}")

        # Plot some predictions
        plt.figure(figsize=(15, 5))

        # Plot survival time predictions
        plt.subplot(1, 2, 1)
        plt.scatter(y_true_time[:50], y_pred_time[:50], alpha=0.6)
        plt.plot([y_true_time.min(), y_true_time.max()],
                [y_true_time.min(), y_true_time.max()], 'r--', lw=2)
        plt.xlabel('Actual Survival Time')
        plt.ylabel('Predicted Survival Time')
        plt.title('Survival Time Predictions')
        plt.grid(True, alpha=0.3)

        # Plot event predictions
        plt.subplot(1, 2, 2)
        plt.bar(['Event=0', 'Event=1'],
                [np.mean(y_pred_event[y_true_event == 0]),
                 np.mean(y_pred_event[y_true_event == 1])])
        plt.xlabel('Actual Event Status')
        plt.ylabel('Mean Predicted Probability')
        plt.title('Event Probability Predictions')
        plt.grid(True, alpha=0.3)

        plt.tight_layout()
        plt.show()

        return lstm_survival_model, preprocessor, results, predictions, y_test_seq

    except FileNotFoundError:
        print("Error: 'pcdata.csv' not found.")
        return None, None, None, None, None
    except Exception as e:
        print(f"An error occurred: {str(e)}")
        import traceback
        traceback.print_exc()
        return None, None, None, None, None


# Run the pipeline
if __name__ == "__main__":
    model, preprocessor, results, predictions, y_test_seq = train_complete_pipeline()

    if model is not None:
        print("\n" + "=" * 70)
        print("PIPELINE COMPLETED SUCCESSFULLY!")
        print("=" * 70)
# Out:
# Starting Autoencoder Imputation + LSTM Survival Prediction Pipeline
# ======================================================================
# Loading data...
#
# ======================================================================
# STAGE 1: Autoencoder-based Imputation
# ======================================================================
# Starting advanced preprocessing with autoencoder imputation...
# WARNING: 65 missing values in VISDAY
# Removed 65 rows with missing VISDAY
# Data after handling missing survival outcomes: 8056 rows
# Selected 34 features for modeling
# === MISSING DATA ANALYSIS ===
# Missing data by column:
#                          missing_count  missing_percentage
# cycle_number                      1969           24.441410
# total_body_systems                1019           12.648957
# max_ae_duration                   1019           12.648957
# most_recent_ae_severity           1019           12.648957
# mean_ae_duration                  1019           12.648957
# total_cycles                         9            0.111718
# Numeric columns: 11
# Categorical columns: 23
#
# Preparing 34 features for autoencoder imputation:
# - Numeric features: 11
# - Categorical features: 23
# Final feature matrix shape: (8056, 68)
# Missing mask shape: (8056, 68)
#
# Data split:
#   Training: (4511, 68)
#   Validation: (1128, 68)
#   Test: (2417, 68)
#
# Training Denoising Autoencoder for imputation...
# Denoising Autoencoder architecture:
# Model: "functional_18"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_16 (InputLayer)     │ (None, 68)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gaussian_noise_7                │ (None, 68)             │             0 │
# │ (GaussianNoise)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_65 (Dense)                │ (None, 128)            │         8,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_42          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_66 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_43          │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_67 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_68 (Dense)                │ (None, 64)             │         2,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_44          │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_69 (Dense)                │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_45          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_70 (Dense)                │ (None, 68)             │         8,772 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 39,908 (155.89 KB)
#  Trainable params: 39,140 (152.89 KB)
#  Non-trainable params: 768 (3.00 KB)
# None
# Training denoising autoencoder with missing-aware loss...
# Epoch 1/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 9s 33ms/step - loss: 1.4733 - val_loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 2/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.4258 - val_loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 3/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2218 - val_loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 4/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1752 - val_loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 5/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1559 - val_loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 6/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1452 - val_loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 7/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1324 - val_loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 8/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1224 - val_loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 9/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1120 - val_loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 10/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1042 - val_loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 11/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0961 - val_loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 12/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0943 - val_loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 13/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0871 - val_loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 14/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0832 - val_loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 15/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0798 - val_loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 16/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0770
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0759 - val_loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 17/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0708 - val_loss: 0.0000e+00 - learning_rate: 5.0000e-04
# Epoch 18/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0705 - val_loss: 0.0000e+00 - learning_rate: 5.0000e-04
# Epoch 19/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0684 - val_loss: 0.0000e+00 - learning_rate: 5.0000e-04
# Epoch 20/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0673 - val_loss: 0.0000e+00 - learning_rate: 5.0000e-04
# Epoch 21/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0658 - val_loss: 0.0000e+00 - learning_rate: 5.0000e-04
# Epoch 22/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0645 - val_loss: 0.0000e+00 - learning_rate: 5.0000e-04
# Epoch 23/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0639 - val_loss: 0.0000e+00 - learning_rate: 5.0000e-04
# Epoch 24/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0630 - val_loss: 0.0000e+00 - learning_rate: 5.0000e-04
# Epoch 25/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0623 - val_loss: 0.0000e+00 - learning_rate: 5.0000e-04
# Epoch 26/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0611 - val_loss: 0.0000e+00 - learning_rate: 5.0000e-04
# Epoch 27/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0601 - val_loss: 0.0000e+00 - learning_rate: 5.0000e-04
# Epoch 28/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0587 - val_loss: 0.0000e+00 - learning_rate: 5.0000e-04
# Epoch 29/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0583 - val_loss: 0.0000e+00 - learning_rate: 5.0000e-04
# Epoch 30/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0571 - val_loss: 0.0000e+00 - learning_rate: 5.0000e-04
# Epoch 31/100
# 61/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0577
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0563 - val_loss: 0.0000e+00 - learning_rate: 5.0000e-04
# Epoch 31: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Imputing missing values...
# Imputing missing values using trained autoencoder...
# Imputed 3382.0 missing values
# Imputing missing values using trained autoencoder...
# Imputed 857.0 missing values
# Imputing missing values using trained autoencoder...
# Imputed 1815.0 missing values
#
# ======================================================================
# STAGE 2: LSTM Survival Prediction
# ======================================================================
#
# Sequence shapes:
#   Training sequences: (1503, 3, 68), labels: (1503, 2)
#   Validation sequences: (376, 3, 68), labels: (376, 2)
#   Test sequences: (805, 3, 68), labels: (805, 2)
#
# Training LSTM Autoencoder for feature extraction...
# LSTM Autoencoder architecture:
# Model: "functional_19"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_17 (InputLayer)     │ (None, 3, 68)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_15 (LSTM)                  │ (None, 3, 64)          │        34,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_16 (LSTM)                  │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ repeat_vector_2 (RepeatVector)  │ (None, 3, 32)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_17 (LSTM)                  │ (None, 3, 32)          │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_18 (LSTM)                  │ (None, 3, 64)          │        24,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_9              │ (None, 3, 68)          │         4,420 │
# │ (TimeDistributed)               │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 84,036 (328.27 KB)
#  Trainable params: 84,036 (328.27 KB)
#  Non-trainable params: 0 (0.00 B)
# None
# Training LSTM autoencoder...
# Epoch 1/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 7s 25ms/step - loss: 2.3959 - mae: 0.4639 - val_loss: 1.7386 - val_mae: 0.4216 - learning_rate: 0.0010
# Epoch 2/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6057 - mae: 0.4120 - val_loss: 1.4702 - val_mae: 0.3938 - learning_rate: 0.0010
# Epoch 3/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4347 - mae: 0.3920 - val_loss: 1.4147 - val_mae: 0.3898 - learning_rate: 0.0010
# Epoch 4/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3844 - mae: 0.3880 - val_loss: 1.3703 - val_mae: 0.3851 - learning_rate: 0.0010
# Epoch 5/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3373 - mae: 0.3836 - val_loss: 1.2937 - val_mae: 0.3802 - learning_rate: 0.0010
# Epoch 6/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.2598 - mae: 0.3784 - val_loss: 1.2120 - val_mae: 0.3725 - learning_rate: 0.0010
# Epoch 7/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.1876 - mae: 0.3705 - val_loss: 1.1460 - val_mae: 0.3622 - learning_rate: 0.0010
# Epoch 8/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.1156 - mae: 0.3604 - val_loss: 1.0855 - val_mae: 0.3540 - learning_rate: 0.0010
# Epoch 9/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.0631 - mae: 0.3532 - val_loss: 1.0424 - val_mae: 0.3496 - learning_rate: 0.0010
# Epoch 10/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.0142 - mae: 0.3478 - val_loss: 1.0020 - val_mae: 0.3461 - learning_rate: 0.0010
# Epoch 11/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.9673 - mae: 0.3416 - val_loss: 0.9526 - val_mae: 0.3376 - learning_rate: 0.0010
# Epoch 12/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9159 - mae: 0.3328 - val_loss: 0.8974 - val_mae: 0.3294 - learning_rate: 0.0010
# Epoch 13/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.8546 - mae: 0.3234 - val_loss: 0.8303 - val_mae: 0.3209 - learning_rate: 0.0010
# Epoch 14/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.7857 - mae: 0.3120 - val_loss: 0.7681 - val_mae: 0.3115 - learning_rate: 0.0010
# Epoch 15/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.7230 - mae: 0.3013 - val_loss: 0.7009 - val_mae: 0.3015 - learning_rate: 0.0010
# Epoch 16/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.6651 - mae: 0.2934 - val_loss: 0.6342 - val_mae: 0.2921 - learning_rate: 0.0010
# Epoch 17/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.6012 - mae: 0.2857 - val_loss: 0.5638 - val_mae: 0.2839 - learning_rate: 0.0010
# Epoch 18/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.5402 - mae: 0.2783 - val_loss: 0.5094 - val_mae: 0.2801 - learning_rate: 0.0010
# Epoch 19/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4816 - mae: 0.2727 - val_loss: 0.4715 - val_mae: 0.2703 - learning_rate: 0.0010
# Epoch 20/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4397 - mae: 0.2657 - val_loss: 0.4326 - val_mae: 0.2646 - learning_rate: 0.0010
# Epoch 21/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.4027 - mae: 0.2597 - val_loss: 0.4125 - val_mae: 0.2609 - learning_rate: 0.0010
# Epoch 22/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.
80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1799 - mae: 0.1827 - val_loss: 0.2063 - val_mae: 0.1908 - learning_rate: 0.0010
# Epoch 75/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1797 - mae: 0.1824 - val_loss: 0.2086 - val_mae: 0.1924 - learning_rate: 0.0010
# Epoch 76/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1767 - mae: 0.1813 - val_loss: 0.2065 - val_mae: 0.1904 - learning_rate: 0.0010
# Epoch 77/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1736 - mae: 0.1796 - val_loss: 0.2058 - val_mae: 0.1908 - learning_rate: 0.0010
# Epoch 78/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1729 - mae: 0.1793 - val_loss: 0.2028 - val_mae: 0.1896 - learning_rate: 0.0010
# Epoch 79/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1718 - mae: 0.1789 - val_loss: 0.2016 - val_mae: 0.1889 - learning_rate: 0.0010
# Epoch 80/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1701 - mae: 0.1782 - val_loss: 0.2010 - val_mae: 0.1888 - learning_rate: 0.0010
# Extracting encoded features...
#
# Training Survival LSTM...
# Survival LSTM architecture:
# Model: "functional_21"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_18      │ (None, 1, 32)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional_7     │ (None, 1, 128)    │     49,664 │ input_layer_18[0… │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_14          │ (None, 1, 128)    │          0 │ bidirectional_7[… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ time_distributed_10 │ (None, 1, 1)      │        129 │ dropout_14[0][0]  │
# │ (TimeDistributed)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ softmax_7 (Softmax) │ (None, 1, 1)      │          0 │ time_distributed… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_7          │ (None, 1, 128)    │          0 │ dropout_14[0][0], │
# │ (Multiply)          │                   │            │ softmax_7[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_7 (Lambda)   │ (None, 128)       │          0 │ multiply_7[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_73 (Dense)    │ (None, 64)        │      8,256 │ lambda_7[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64)        │        256 │ dense_73[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_15          │ (None, 64)        │          0 │ batch_normalizat… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_74 (Dense)    │ (None, 32)        │      2,080 │ dropout_15[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32)        │        128 │ dense_74[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ survival_time       │ (None, 1)         │         33 │ batch_normalizat… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ event (Dense)       │ (None, 1)         │         33 │ batch_normalizat… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 60,579 (236.64 KB)
#  Trainable params: 60,387 (235.89 KB)
#  Non-trainable params: 192 (768.00 B)
# None
# Training Survival LSTM...
# Epoch 1/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - event_accuracy: 0.4957 - event_auc_7: 0.4564 - event_loss: 0.9010 - loss: 18687.8555 - survival_time_loss: 31146.4043 - survival_time_mae: 133.1516 - survival_time_root_mean_squared_error: 176.2951 - val_event_accuracy: 0.8617 - val_event_auc_7: 0.4758 - val_event_loss: 0.6404 - val_loss: 20005.5957 - val_survival_time_loss: 33687.0117 - val_survival_time_mae: 134.0373 - val_survival_time_root_mean_squared_error: 182.5986 - learning_rate: 5.0000e-04
# Epoch 2/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - event_accuracy: 0.5350 - event_auc_7: 0.4840 - event_loss: 0.7968 - loss: 18412.9531 - survival_time_loss: 30688.3008 - survival_time_mae: 131.8811 - survival_time_root_mean_squared_error: 174.9937 - val_event_accuracy: 0.8617 - val_event_auc_7: 0.5304 - val_event_loss: 0.6014 - val_loss: 19884.1523 - val_survival_time_loss: 33485.3516 - val_survival_time_mae: 133.4519 - val_survival_time_root_mean_squared_error: 182.0435 - learning_rate: 5.0000e-04
# Epoch 3/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - event_accuracy: 0.5463 - event_auc_7: 0.4736 - event_loss: 0.7594 - loss: 18148.3438 - survival_time_loss: 30247.3145 - survival_time_mae: 130.7740 - survival_time_root_mean_squared_error: 173.7266 - val_event_accuracy: 0.8617 - val_event_auc_7: 0.5325 - val_event_loss: 0.5779 - val_loss: 19734.6113 - val_survival_time_loss: 33236.5664 - val_survival_time_mae: 132.8151 - val_survival_time_root_mean_squared_error: 181.3577 - learning_rate: 5.0000e-04
# Epoch 4/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - event_accuracy: 0.5501 - event_auc_7: 0.4941 - event_loss: 0.7222 - loss: 17929.5918 - survival_time_loss: 29882.7539 - survival_time_mae: 129.8393 - survival_time_root_mean_squared_error: 172.6743 - val_event_accuracy: 0.8617 - val_event_auc_7: 0.5117 - val_event_loss: 0.5847 - val_loss: 19569.8320 - val_survival_time_loss: 32962.1836 - val_survival_time_mae: 132.2152 - val_survival_time_root_mean_squared_error: 180.5990 - learning_rate: 5.0000e-04
# Epoch 5/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - event_accuracy: 0.5270 - event_auc_7: 0.4309 - event_loss: 0.7161 - loss: 17704.0742 - survival_time_loss: 29506.8848 - survival_time_mae: 128.9708 - survival_time_root_mean_squared_error: 171.5813 - val_event_accuracy: 0.8617 - val_event_auc_7: 0.5175 - val_event_loss: 0.5918 - val_loss: 19438.0957 - val_survival_time_loss: 32742.9297 - val_survival_time_mae: 131.8789 - val_survival_time_root_mean_squared_error: 179.9901 - learning_rate: 5.0000e-04
# Epoch 6/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - event_accuracy: 0.5499 - event_auc_7: 0.4319 - event_loss: 0.6954 - loss: 17466.8828 - survival_time_loss: 29111.5801 - survival_time_mae: 128.0647 - survival_time_root_mean_squared_error: 170.4266 - val_event_accuracy: 0.8590 - val_event_auc_7: 0.5243 - val_event_loss: 0.6141 - val_loss: 19184.0566 - val_survival_time_loss: 32319.8262 - val_survival_time_mae: 130.9528 - val_survival_time_root_mean_squared_error: 178.8100 - learning_rate: 5.0000e-04
# Epoch 7/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - event_accuracy: 0.5845 - event_auc_7: 0.4983 - event_loss: 0.6718 - loss: 17223.7754 - survival_time_loss: 28706.4160 - survival_time_mae: 127.0880 - survival_time_root_mean_squared_error: 169.2336 - val_event_accuracy: 0.8298 - val_event_auc_7: 0.5079 - val_event_loss: 0.6180 - val_loss: 18832.1836 - val_survival_time_loss: 31733.6270 - val_survival_time_mae: 129.6257 - val_survival_time_root_mean_squared_error: 177.1625 - learning_rate: 5.0000e-04
# Epoch 8/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - event_accuracy: 0.6085 - event_auc_7: 0.5306 - event_loss: 0.6530 - loss: 16945.0723 - survival_time_loss: 28241.9277 - survival_time_mae: 126.0149 - survival_time_root_mean_squared_error: 167.8540 - val_event_accuracy: 0.7872 - val_event_auc_7: 0.5318 - val_event_loss: 0.6187 - val_loss: 18541.6465 - val_survival_time_loss: 31248.4531 - val_survival_time_mae: 128.7207 - val_survival_time_root_mean_squared_error: 175.7906 - learning_rate: 5.0000e-04
# Epoch 9/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - event_accuracy: 0.6242 - event_auc_7: 0.5292 - event_loss: 0.6419 - loss: 16689.4238 - survival_time_loss: 27815.8457 - survival_time_mae: 125.0288 - survival_time_root_mean_squared_error: 166.5798 - val_event_accuracy: 0.8324 - val_event_auc_7: 0.5212 - val_event_loss: 0.6046 - val_loss: 18141.7129 - val_survival_time_loss: 30582.2363 - val_survival_time_mae: 127.2147 - val_survival_time_root_mean_squared_error: 173.8844 - learning_rate: 5.0000e-04
# Epoch 10/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - event_accuracy: 0.6302 - event_auc_7: 0.5372 - event_loss: 0.6329 - loss: 16455.1934 - survival_time_loss: 27425.4668 - survival_time_mae: 123.9745 - survival_time_root_mean_squared_error: 165.4006 - val_event_accuracy: 0.6569 - val_event_auc_7: 0.5158 - val_event_loss: 0.6121 - val_loss: 17610.3359 - val_survival_time_loss: 29695.4688 - val_survival_time_mae: 124.9458 - val_survival_time_root_mean_squared_error: 171.3189 - learning_rate: 5.0000e-04
# Epoch 11/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - event_accuracy: 0.6263 - event_auc_7: 0.4795 - event_loss: 0.6311 - loss: 16179.2178 - survival_time_loss: 26965.5176 - survival_time_mae: 122.7458 - survival_time_root_mean_squared_error: 164.0084 - val_event_accuracy: 0.5612 - val_event_auc_7: 0.5061 - val_event_loss: 0.6186 - val_loss: 17190.7031 - val_survival_time_loss: 28995.8418 - val_survival_time_mae: 123.3397 - val_survival_time_root_mean_squared_error: 169.2654 - learning_rate: 5.0000e-04
# Epoch 12/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - event_accuracy: 0.6461 - event_auc_7: 0.5144 - event_loss: 0.6151 - loss: 15936.7480 - survival_time_loss: 26561.4102 - survival_time_mae: 121.6599 - survival_time_root_mean_squared_error: 162.7732 - val_event_accuracy: 0.5186 - val_event_auc_7: 0.5208 - val_event_loss: 0.6174 - val_loss: 16844.1816 - val_survival_time_loss: 28418.8984 - val_survival_time_mae: 122.1237 - val_survival_time_root_mean_squared_error: 167.5507 - learning_rate: 5.0000e-04
# Epoch 13/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - event_accuracy: 0.6707 - event_auc_7: 0.5233 - event_loss: 0.6060 - loss: 15640.2236 - survival_time_loss: 26067.2031 - survival_time_mae: 120.4796 - survival_time_root_mean_squared_error: 161.2507 - val_event_accuracy: 0.5452 - val_event_auc_7: 0.5203 - val_event_loss: 0.6105 - val_loss: 16534.5547 - val_survival_time_loss: 27904.8184 - val_survival_time_mae: 120.9387 - val_survival_time_root_mean_squared_error: 166.0036 - learning_rate: 5.0000e-04
# Epoch 14/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - event_accuracy: 0.6792 - event_auc_7: 0.5140 - event_loss: 0.6013 - loss: 15375.6875 - survival_time_loss: 25626.3086 - survival_time_mae: 119.3128 - survival_time_root_mean_squared_error: 159.8767 - val_event_accuracy: 0.5399 - val_event_auc_7: 0.5251 - val_event_loss: 0.6006 - val_loss: 15995.4482 - val_survival_time_loss: 27002.7500 - val_survival_time_mae: 118.5284 - val_survival_time_root_mean_squared_error: 163.2749 - learning_rate: 5.0000e-04
# Epoch 15/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - event_accuracy: 0.6762 - event_auc_7: 0.5005 - event_loss: 0.5953 - loss: 15041.8145 - survival_time_loss: 25069.8438 - survival_time_mae: 117.9778 - survival_time_root_mean_squared_error: 158.1203 - val_event_accuracy: 0.6622 - val_event_auc_7: 0.5365 - val_event_loss: 0.5711 - val_loss: 15325.0029 - val_survival_time_loss: 25850.8809 - val_survival_time_mae: 114.8116 - val_survival_time_root_mean_squared_error: 159.8164 - learning_rate: 5.0000e-04
# Epoch 16/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - event_accuracy: 0.6900 - event_auc_7: 0.5267 - event_loss: 0.5838 - loss: 14646.5645 - survival_time_loss: 24411.1035 - survival_time_mae: 116.0619 - survival_time_root_mean_squared_error: 156.0254 - val_event_accuracy: 0.6436 - val_event_auc_7: 0.5476 - val_event_loss: 0.5568 - val_loss: 14801.3643 - val_survival_time_loss: 24973.3906 - val_survival_time_mae: 112.0670 - val_survival_time_root_mean_squared_error: 157.0623 - learning_rate: 5.0000e-04
# Epoch 17/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - event_accuracy: 0.6993 - event_auc_7: 0.5607 - event_loss: 0.5667 - loss: 14276.1133 - survival_time_loss: 23793.6855 - survival_time_mae: 114.5514 - survival_time_root_mean_squared_error: 154.0352 - val_event_accuracy: 0.6755 - val_event_auc_7: 0.5460 - val_event_loss: 0.5605 - val_loss: 14715.4199 - val_survival_time_loss: 24834.6973 - val_survival_time_mae: 112.2421 - val_survival_time_root_mean_squared_error: 156.6056 - learning_rate: 5.0000e-04
# Epoch 18/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - event_accuracy: 0.7085 - event_auc_7: 0.5433 - event_loss: 0.5631 - loss: 13988.1006 - survival_time_loss: 23313.6641 - survival_time_mae: 113.0951 - survival_time_root_mean_squared_error: 152.4732 - val_event_accuracy: 0.6862 - val_event_auc_7: 0.5496 - val_event_loss: 0.5542 - val_loss: 14247.9004 - val_survival_time_loss: 24045.2012 - val_survival_time_mae: 109.7037 - val_survival_time_root_mean_squared_error: 154.0978 - learning_rate: 5.0000e-04
# Epoch 19/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - event_accuracy: 0.7350 - event_auc_7: 0.5280 - event_loss: 0.5602 - loss: 13611.5596 - survival_time_loss: 22686.1152 - survival_time_mae: 111.4557 - survival_time_root_mean_squared_error: 150.3922 - val_event_accuracy: 0.6782 - val_event_auc_7: 0.5445 - val_event_loss: 0.5528 - val_loss: 14151.9922 - val_survival_time_loss: 23884.6660 - val_survival_time_mae: 109.7625 - val_survival_time_root_mean_squared_error: 153.5782 - learning_rate: 5.0000e-04
# Epoch 20/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - event_accuracy: 0.7497 - event_auc_7: 0.5519 - event_loss: 0.5462 - loss: 13307.8594 - survival_time_loss: 22179.9316 - survival_time_mae: 109.7329 - survival_time_root_mean_squared_error: 148.7010 - val_event_accuracy: 0.7553 - val_event_auc_7: 0.5447 - val_event_loss: 0.5432 - val_loss: 13722.0527 - val_survival_time_loss: 23169.9316 - val_survival_time_mae: 107.7295 - val_survival_time_root_mean_squared_error: 151.2274 - learning_rate: 5.0000e-04
# Epoch 21/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - event_accuracy: 0.7509 - event_auc_7: 0.5306 - event_loss: 0.5443 - loss: 12952.2471 - survival_time_loss: 21587.2402 - survival_time_mae: 108.2294 - survival_time_root_mean_squared_error: 146.6918 - val_event_accuracy: 0.8271 - val_event_auc_7: 0.5431 - val_event_loss: 0.5321 - val_loss: 13429.7764 - val_survival_time_loss: 22671.7031 - val_survival_time_mae: 106.4652 - val_survival_time_root_mean_squared_error: 149.6082 - learning_rate: 5.0000e-04
# Epoch 22/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - event_accuracy: 0.7658 - event_auc_7: 0.5134 - event_loss: 0.5396 - loss: 12625.6855 - survival_time_loss: 21042.9883 - survival_time_mae: 106.6836 - survival_time_root_mean_squared_error: 144.8351 - val_event_accuracy: 0.8457 - val_event_auc_7: 0.5580 - val_event_loss: 0.5199 - val_loss: 13183.9033 - val_survival_time_loss: 22266.5059 - val_survival_time_mae: 104.8383 - val_survival_time_root_mean_squared_error: 148.2323 - learning_rate: 5.0000e-04
# Epoch 23/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - event_accuracy: 0.7595 - event_auc_7: 0.5216 - event_loss: 0.5338 - loss: 12320.4863 - survival_time_loss: 20534.3164 - survival_time_mae: 105.1448 - survival_time_root_mean_squared_error: 143.0703 - val_event_accuracy: 0.8537 - val_event_auc_7: 0.5504 - val_event_loss: 0.5174 - val_loss: 12659.5254 - val_survival_time_loss: 21380.4336 - val_survival_time_mae: 102.6665 - val_survival_time_root_mean_squared_error: 145.2545 - learning_rate: 5.0000e-04
# Epoch 24/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - event_accuracy: 0
- val_event_accuracy: 0.8617 - val_event_auc_7: 0.5469 - val_event_loss: 0.4051 - val_loss: 3738.1812 - val_survival_time_loss: 6398.2046 - val_survival_time_mae: 52.2039 - val_survival_time_root_mean_squared_error: 78.9305 - learning_rate: 5.0000e-04
# Epoch 114/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - event_accuracy: 0.8690 - event_auc_7: 0.4904 - event_loss: 0.4050 - loss: 2941.1943 - survival_time_loss: 4901.9414 - survival_time_mae: 51.1048 - survival_time_root_mean_squared_error: 69.7256 - val_event_accuracy: 0.8617 - val_event_auc_7: 0.5459 - val_event_loss: 0.4045 - val_loss: 3772.5396 - val_survival_time_loss: 6440.6401 - val_survival_time_mae: 52.5772 - val_survival_time_root_mean_squared_error: 79.2925 - learning_rate: 5.0000e-04
# Epoch 115/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - event_accuracy: 0.8681 - event_auc_7: 0.4919 - event_loss: 0.4062 - loss: 2834.3813 - survival_time_loss: 4723.9229 - survival_time_mae: 49.5288 - survival_time_root_mean_squared_error: 68.3425 - val_event_accuracy: 0.8617 - val_event_auc_7: 0.5484 - val_event_loss: 0.4046 - val_loss: 3780.2812 - val_survival_time_loss: 6467.0649 - val_survival_time_mae: 52.4230 - val_survival_time_root_mean_squared_error: 79.3738 - learning_rate: 5.0000e-04
# Epoch 116/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - event_accuracy: 0.8696 - event_auc_7: 0.4846 - event_loss: 0.4018 - loss: 2855.8494 - survival_time_loss: 4759.6367 - survival_time_mae: 50.3555 - survival_time_root_mean_squared_error: 68.7663 - val_event_accuracy: 0.8617 - val_event_auc_7: 0.5445 - val_event_loss: 0.4039 - val_loss: 3785.5635 - val_survival_time_loss: 6456.9136 - val_survival_time_mae: 52.5199 - val_survival_time_root_mean_squared_error: 79.4292 - learning_rate: 5.0000e-04
# Epoch 117/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - event_accuracy: 0.8684 - event_auc_7: 0.4853 - event_loss: 0.4060 - loss: 2977.6460 - survival_time_loss: 4962.6812 - survival_time_mae: 52.2528 - survival_time_root_mean_squared_error: 70.2571 - val_event_accuracy: 0.8617 - val_event_auc_7: 0.5470 - val_event_loss: 0.4041 - val_loss: 3666.7539 - val_survival_time_loss: 6275.2720 - val_survival_time_mae: 51.2933 - val_survival_time_root_mean_squared_error: 78.1728 - learning_rate: 5.0000e-04
# Epoch 118/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - event_accuracy: 0.8703 - event_auc_7: 0.5200 - event_loss: 0.3984 - loss: 2858.6799 - survival_time_loss: 4764.3765 - survival_time_mae: 50.3654 - survival_time_root_mean_squared_error: 68.8497 - val_event_accuracy: 0.8617 - val_event_auc_7: 0.5276 - val_event_loss: 0.4054 - val_loss: 3776.0581 - val_survival_time_loss: 6459.5591 - val_survival_time_mae: 52.3496 - val_survival_time_root_mean_squared_error: 79.3294 - learning_rate: 5.0000e-04
# Epoch 119/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - event_accuracy: 0.8698 - event_auc_7: 0.5049 - event_loss: 0.3997 - loss: 3098.9404 - survival_time_loss: 5164.8623 - survival_time_mae: 53.0470 - survival_time_root_mean_squared_error: 71.6233 - val_event_accuracy: 0.8617 - val_event_auc_7: 0.5448 - val_event_loss: 0.4047 - val_loss: 3797.8831 - val_survival_time_loss: 6489.5396 - val_survival_time_mae: 52.0998 - val_survival_time_root_mean_squared_error: 79.5584 - learning_rate: 5.0000e-04
# Epoch 120/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - event_accuracy: 0.8698 - event_auc_7: 0.4766 - event_loss: 0.4041 - loss: 2978.3523 - survival_time_loss: 4963.8755 - survival_time_mae: 51.4326 - survival_time_root_mean_squared_error: 70.2467 - val_event_accuracy: 0.8617 - val_event_auc_7: 0.5392 - val_event_loss: 0.4045 - val_loss: 3721.4075 - val_survival_time_loss: 6358.4316 - val_survival_time_mae: 51.6401 - val_survival_time_root_mean_squared_error: 78.7532 - learning_rate: 5.0000e-04
# ======================================================================
# MODEL EVALUATION
# ======================================================================
# Evaluating model...
#
# Evaluation Results:
# loss: 3970.5015
# compile_metrics: 6728.6450
# survival_time_loss: 0.4111
# event_loss: 0.8646
#
# Detailed Performance Metrics:
#
# Survival Time Prediction:
#   MSE: 6617.2347
#   MAE: 54.4095
#   RMSE: 81.3464
#
# Event Prediction:
#   Accuracy: 0.8646
#   AUC-ROC: 0.5430
# ======================================================================
# PIPELINE COMPLETED SUCCESSFULLY!
# ======================================================================

# %%
# ... (all the previous code remains the same until the train_complete_pipeline function) ...

def train_complete_pipeline():
    """Complete training pipeline with autoencoder imputation"""
    print("Starting Autoencoder Imputation + LSTM Survival Prediction Pipeline")
    print("=" * 70)

    try:
        # Load data
        print("Loading data...")
        pcdata = pd.read_csv('pcdata.csv')

        # Initialize preprocessor
        preprocessor = SurvivalDataPreprocessor()

        # Preprocess with autoencoder imputation
        print("\n" + "=" * 70)
        print("STAGE 1: Autoencoder-based Imputation")
        print("=" * 70)

        X_prepared, missing_mask, survival_data, all_columns, features = \
            preprocessor.preprocess_for_autoencoder_imputation(pcdata)

        # Split data
        X_train, X_test, mask_train, mask_test, y_train, y_test = train_test_split(
            X_prepared, missing_mask, survival_data,
            test_size=0.3, random_state=42
        )

        X_train, X_val, mask_train, mask_val, y_train, y_val = train_test_split(
            X_train, mask_train, y_train,
            test_size=0.2, random_state=42
        )

        print(f"\nData split:")
        print(f"  Training: {X_train.shape}")
        print(f"  Validation: {X_val.shape}")
        print(f"  Test: {X_test.shape}")

        # Initialize and train denoising autoencoder for imputation
        print("\nTraining Denoising Autoencoder for imputation...")
        autoencoder_imputer = DenoisingAutoencoderImputer(
            input_dim=X_train.shape[1],
            encoding_dim=32,
            noise_factor=0.1
        )

        autoencoder_imputer.build_autoencoder()

        # Explicitly cast data to tf.float32 to prevent dtype mismatch errors
        X_train_tf = tf.cast(X_train, tf.float32)
        mask_train_tf = tf.cast(mask_train, tf.float32)
        X_val_tf = tf.cast(X_val, tf.float32)
        mask_val_tf = tf.cast(mask_val, tf.float32)

        autoencoder_imputer.train_with_missing_awareness(
            X_train_tf, mask_train_tf,
            X_val_tf, mask_val_tf,
            epochs=100,
            batch_size=64
        )

        # Impute missing values
        print("\nImputing missing values...")
        X_train_imputed = autoencoder_imputer.impute_missing_values(X_train_tf, mask_train_tf)
        X_val_imputed = autoencoder_imputer.impute_missing_values(X_val_tf, mask_val_tf)
        X_test_imputed = autoencoder_imputer.impute_missing_values(tf.cast(X_test, tf.float32), tf.cast(mask_test, tf.float32))

        preprocessor.autoencoder_imputer = autoencoder_imputer

        print("\n" + "=" * 70)
        print("STAGE 2: LSTM Survival Prediction")
        print("=" * 70)

        # Create sequences for LSTM
        sequence_length = 3

        # For simplicity, create synthetic sequences from the data
        def create_synthetic_sequences(X, y, seq_length):
            n_sequences = len(X) // seq_length
            X_seq = X[:n_sequences * seq_length].reshape(n_sequences, seq_length, -1)
            y_seq = y[:n_sequences * seq_length].reshape(n_sequences, seq_length, -1)
            # Use last time point for prediction
            y_seq = y_seq[:, -1, :]
            return X_seq, y_seq

        X_train_seq, y_train_seq = create_synthetic_sequences(X_train_imputed, y_train, sequence_length)
        X_val_seq, y_val_seq = create_synthetic_sequences(X_val_imputed, y_val, sequence_length)
        X_test_seq, y_test_seq = create_synthetic_sequences(X_test_imputed, y_test, sequence_length)

        print(f"\nSequence shapes:")
        print(f"  Training sequences: {X_train_seq.shape}, labels: {y_train_seq.shape}")
        print(f"  Validation sequences: {X_val_seq.shape}, labels: {y_val_seq.shape}")
        print(f"  Test sequences: {X_test_seq.shape}, labels: {y_test_seq.shape}")

        # Initialize and train LSTM autoencoder for feature extraction
        print("\nTraining LSTM Autoencoder for feature extraction...")
        lstm_ae = AutoencoderLSTM_Survival(
            input_dim=X_train_seq.shape[2],
            encoding_dim=32,
            sequence_length=sequence_length,
            lstm_units=64
        )

        lstm_ae.build_lstm_autoencoder()
        lstm_ae.train_lstm_autoencoder(
            X_train_seq, X_val_seq,
            epochs=80,
            batch_size=32
        )

        # Extract encoded features
        print("\nExtracting encoded features...")
        X_train_encoded = lstm_ae.encoder.predict(X_train_seq, verbose=0)
        X_val_encoded = lstm_ae.encoder.predict(X_val_seq, verbose=0)
        X_test_encoded = lstm_ae.encoder.predict(X_test_seq, verbose=0)

        # Reshape for survival LSTM
        X_train_encoded_seq = X_train_encoded.reshape(-1, 1, X_train_encoded.shape[1])
        X_val_encoded_seq = X_val_encoded.reshape(-1, 1, X_val_encoded.shape[1])
        X_test_encoded_seq = X_test_encoded.reshape(-1, 1, X_test_encoded.shape[1])

        # Initialize and train Survival LSTM
        print("\nTraining Survival LSTM...")
        lstm_survival_model = AutoencoderLSTM_Survival(
            input_dim=lstm_ae.encoding_dim,
            encoding_dim=lstm_ae.encoding_dim,
            sequence_length=1,
            lstm_units=lstm_ae.lstm_units
        )
        lstm_survival_model.build_survival_lstm()
        lstm_survival_model.train_survival_lstm(
            X_train_encoded_seq, y_train_seq,
            X_val_encoded_seq, y_val_seq,
            epochs=120,
            batch_size=32
        )

        # Evaluate
        print("\n" + "=" * 70)
        print("MODEL EVALUATION")
        print("=" * 70)

        results = lstm_survival_model.evaluate(X_test_encoded_seq, y_test_seq)

        # Make predictions
        predictions = lstm_survival_model.predict(X_test_encoded_seq)

        # Calculate additional metrics
        from sklearn.metrics import mean_squared_error, mean_absolute_error, accuracy_score, roc_auc_score

        # Survival time metrics
        y_pred_time = predictions[0].flatten()
        y_true_time = y_test_seq[:, 0]

        mse_time = mean_squared_error(y_true_time, y_pred_time)
        mae_time = mean_absolute_error(y_true_time, y_pred_time)
        rmse_time = np.sqrt(mse_time)

        # Event prediction metrics
        y_pred_event = predictions[1].flatten()
        y_pred_event_binary = (y_pred_event > 0.5).astype(int)
        y_true_event = y_test_seq[:, 1]

        event_accuracy = accuracy_score(y_true_event, y_pred_event_binary)
        event_auc = roc_auc_score(y_true_event, y_pred_event)

        print("\nDetailed Performance Metrics:")
        print(f"\nSurvival Time Prediction:")
        print(f"  MSE: {mse_time:.4f}")
        print(f"  MAE: {mae_time:.4f}")
        print(f"  RMSE: {rmse_time:.4f}")

        print(f"\nEvent Prediction:")
        print(f"  Accuracy: {event_accuracy:.4f}")
        print(f"  AUC-ROC: {event_auc:.4f}")

        # Plot some predictions
        plt.figure(figsize=(15, 5))

        # Plot survival time predictions
        plt.subplot(1, 2, 1)
        plt.scatter(y_true_time[:50], y_pred_time[:50], alpha=0.6)
        plt.plot([y_true_time.min(), y_true_time.max()],
                [y_true_time.min(), y_true_time.max()], 'r--', lw=2)
        plt.xlabel('Actual Survival Time')
        plt.ylabel('Predicted Survival Time')
        plt.title('Survival Time Predictions')
        plt.grid(True, alpha=0.3)

        # Plot event predictions
        plt.subplot(1, 2, 2)
        plt.bar(['Event=0', 'Event=1'],
                [np.mean(y_pred_event[y_true_event == 0]),
                 np.mean(y_pred_event[y_true_event == 1])])
        plt.xlabel('Actual Event Status')
        plt.ylabel('Mean Predicted Probability')
        plt.title('Event Probability Predictions')
        plt.grid(True, alpha=0.3)

        plt.tight_layout()
        plt.show()

        print("\n" + "=" * 70)
        print("ADDITIONAL PLOTS")
        print("=" * 70)

        # ========== ADDED PLOTS ==========

        # 1. Histogram of risk scores color-coded by event status
        plt.figure(figsize=(14, 10))

        # Create risk scores from predicted probabilities
        risk_scores = y_pred_event

        # Plot histogram
        plt.subplot(2, 2, 1)
        plt.hist(risk_scores[y_true_event == 0], bins=30, alpha=0.5, label='No Event', color='blue')
        plt.hist(risk_scores[y_true_event == 1], bins=30, alpha=0.5, label='Event', color='red')
        plt.xlabel('Risk Score (Predicted Probability)')
        plt.ylabel('Frequency')
        plt.title('Histogram of Risk Scores by Event Status')
        plt.legend()
        plt.grid(True, alpha=0.3)

        # 2. Sensitivity and Specificity plot
        from sklearn.metrics import roc_curve

        # Calculate ROC curve
        fpr, tpr, thresholds = roc_curve(y_true_event, risk_scores)

        # Calculate sensitivity (TPR) and specificity (1-FPR)
        specificity = 1 - fpr
        sensitivity = tpr

        # FIX: thresholds has one more element than sensitivity/specificity
        # Use thresholds[:-1] to match dimensions
        plt.subplot(2, 2, 2)
        plt.plot(thresholds[:-1], sensitivity[:-1], 'b-', label='Sensitivity', linewidth=2)
        plt.plot(thresholds[:-1], specificity[:-1], 'r-', label='Specificity', linewidth=2)
        plt.xlabel('Risk Score Threshold')
        plt.ylabel('Value')
        plt.title('Sensitivity and Specificity vs Risk Score Threshold')
        plt.legend()
        plt.grid(True, alpha=0.3)
        plt.xlim([0, 1])
        plt.ylim([0, 1])

        # 3. PPV and NPV plot
        from sklearn.metrics import precision_score, recall_score

        # Calculate PPV (Positive Predictive Value) and NPV (Negative Predictive Value) for different thresholds
        thresholds_ppv_npv = np.linspace(0, 1, 50)
        ppv_values = []
        npv_values = []

        for threshold in thresholds_ppv_npv:
            y_pred_binary = (risk_scores >= threshold).astype(int)

            # Calculate PPV (precision)
            if sum(y_pred_binary) > 0:
                ppv = precision_score(y_true_event, y_pred_binary, zero_division=0)
            else:
                ppv = 0

            # Calculate NPV
            # True negatives / (true negatives + false negatives)
            tn = sum((y_pred_binary == 0) & (y_true_event == 0))
            fn = sum((y_pred_binary == 0) & (y_true_event == 1))
            if (tn + fn) > 0:
                npv = tn / (tn + fn)
            else:
                npv = 0

            ppv_values.append(ppv)
            npv_values.append(npv)

        plt.subplot(2, 2, 3)
        plt.plot(thresholds_ppv_npv, ppv_values, 'b-', label='PPV', linewidth=2)
        plt.plot(thresholds_ppv_npv, npv_values, 'r-', label='NPV', linewidth=2)
        plt.xlabel('Risk Score Threshold')
        plt.ylabel('Value')
        plt.title('PPV and NPV vs Risk Score Threshold')
        plt.legend()
        plt.grid(True, alpha=0.3)
        plt.xlim([0, 1])
        plt.ylim([0, 1])

        # 4. Predicted vs Observed probabilities (calibration plot)
        from sklearn.calibration import calibration_curve

        # Calculate calibration curve
        prob_true, prob_pred = calibration_curve(y_true_event, risk_scores, n_bins=10, strategy='uniform')

        plt.subplot(2, 2, 4)
        plt.plot(prob_pred, prob_true, 'bo-', linewidth=2, markersize=8, label='Model')
        plt.plot([0, 1], [0, 1], 'r--', linewidth=2, label='Perfect Calibration')
        plt.xlabel('Mean Predicted Probability')
        plt.ylabel('Fraction of Positives')
        plt.title('Calibration Plot: Predicted vs Observed Probabilities')
        plt.legend()
        plt.grid(True, alpha=0.3)
        plt.xlim([0, 1])
        plt.ylim([0, 1])

        plt.tight_layout()
        plt.show()

        # 5. Additional detailed plot: Risk score distribution by decile
        plt.figure(figsize=(12, 5))

        # Create deciles of risk scores
        risk_score_deciles = pd.qcut(risk_scores, q=10, labels=False, duplicates='drop')

        # Calculate event rates in each decile
        event_rates_by_decile = []
        decile_centers = []

        for decile in range(min(10, len(np.unique(risk_score_deciles)))):
            decile_indices = risk_score_deciles == decile
            if sum(decile_indices) > 0:
                event_rate = np.mean(y_true_event[decile_indices])
                event_rates_by_decile.append(event_rate)
                # Use median risk score in decile as center
                decile_center = np.median(risk_scores[decile_indices])
                decile_centers.append(decile_center)

        plt.subplot(1, 2, 1)
        plt.plot(decile_centers, event_rates_by_decile, 'bo-', linewidth=2, markersize=8)
        plt.plot([0, 1], [0, 1], 'r--', linewidth=2, label='Perfect Prediction')
        plt.xlabel('Median Predicted Risk in Decile')
        plt.ylabel('Observed Event Rate')
        plt.title('Calibration by Risk Decile')
        plt.legend()
        plt.grid(True, alpha=0.3)
        plt.xlim([0, 1])
        plt.ylim([0, 1])

        # Bar plot of event rates by decile
        plt.subplot(1, 2, 2)
        n_deciles = len(event_rates_by_decile)
        decile_labels = [f'D{i+1}' for i in range(n_deciles)]
        colors = plt.cm.RdYlBu(np.linspace(0, 1, n_deciles))
        bars = plt.bar(decile_labels, event_rates_by_decile, color=colors)
        plt.xlabel('Risk Score Decile')
        plt.ylabel('Observed Event Rate')
        plt.title('Event Rate by Risk Decile')
        plt.grid(True, alpha=0.3, axis='y')

        # Add value labels on bars
        for bar, rate in zip(bars, event_rates_by_decile):
            height = bar.get_height()
            plt.text(bar.get_x() + bar.get_width()/2., height + 0.01,
                    f'{rate:.2f}', ha='center', va='bottom', fontsize=9)

        plt.tight_layout()
        plt.show()

        # 6. Additional: Show ROC curve with AUC
        plt.figure(figsize=(10, 8))

        # Calculate AUC
        from sklearn.metrics import auc
        roc_auc = auc(fpr, tpr)

        plt.plot(fpr, tpr, 'b-', label=f'ROC curve (AUC = {roc_auc:.3f})', linewidth=2)
        plt.plot([0, 1], [0, 1], 'r--', label='Random', linewidth=2)
        plt.xlim([0.0, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel('False Positive Rate (1 - Specificity)')
        plt.ylabel('True Positive Rate (Sensitivity)')
        plt.title('Receiver Operating Characteristic (ROC) Curve')
        plt.legend(loc="lower right")
        plt.grid(True, alpha=0.3)

        plt.tight_layout()
        plt.show()

        return lstm_survival_model, preprocessor, results, predictions, y_test_seq
    except FileNotFoundError:
        print("Error: 'pcdata.csv' not found.")
        return None, None, None, None, None
    except Exception as e:
        print(f"An error occurred: {str(e)}")
        import traceback
        traceback.print_exc()
        return None, None, None, None, None


# Run the pipeline
if __name__ == "__main__":
    model, preprocessor, results, predictions, y_test_seq = train_complete_pipeline()

    if model is not None:
        print("\n" + "=" * 70)
        print("PIPELINE COMPLETED SUCCESSFULLY!")
        print("=" * 70)
# Out:
# Starting Autoencoder Imputation + LSTM Survival Prediction Pipeline
# ======================================================================
# Loading data...
#
# ======================================================================
# STAGE 1: Autoencoder-based Imputation
# ======================================================================
# Starting advanced preprocessing with autoencoder imputation...
# WARNING: 65 missing values in VISDAY
# Removed 65 rows with missing VISDAY
# Data after handling missing survival outcomes: 8056 rows
# Selected 34 features for modeling
# === MISSING DATA ANALYSIS ===
# Missing data by column:
#                          missing_count  missing_percentage
# cycle_number                      1969           24.441410
# total_body_systems                1019           12.648957
# max_ae_duration                   1019           12.648957
# most_recent_ae_severity           1019           12.648957
# mean_ae_duration                  1019           12.648957
# total_cycles                         9            0.111718
# Numeric columns: 11
# Categorical columns: 23
#
# Preparing 34 features for autoencoder imputation:
# - Numeric features: 11
# - Categorical features: 23
# Final feature matrix shape: (8056, 68)
# Missing mask shape: (8056, 68)
#
# Data split:
#   Training: (4511, 68)
#   Validation: (1128, 68)
#   Test: (2417, 68)
#
# Training Denoising Autoencoder for imputation...
# Denoising Autoencoder architecture:
# Model: "functional_26"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_22 (InputLayer)     │ (None, 68)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gaussian_noise_9                │ (None, 68)             │             0 │
# │ (GaussianNoise)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_85 (Dense)                │ (None, 128)            │         8,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_54          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_86 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_55          │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_87 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_88 (Dense)                │ (None, 64)             │         2,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_56          │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_89 (Dense)                │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_57          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_90 (Dense)                │ (None, 68)             │         8,772 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 39,908 (155.89 KB)
#  Trainable params: 39,140 (152.89 KB)
#  Non-trainable params: 768 (3.00 KB)
# None
# Training denoising autoencoder with missing-aware loss...
# Epoch 1/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 1.5110 - val_loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 2/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4353 - val_loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 3/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2144 - val_loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 4/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1705 - val_loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 5/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1539 - val_loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 6/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1416 - val_loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 7/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1323 - val_loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 8/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1227 - val_loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 9/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1112 - val_loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 10/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1040 - val_loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 11/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0966 - val_loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 12/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0901 - val_loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 13/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0875 - val_loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 14/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0824 - val_loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 15/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0791 - val_loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 16/100
# 67/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0753
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0755 - val_loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 17/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0707 - val_loss: 0.0000e+00 - learning_rate: 5.0000e-04
# Epoch 18/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0693 - val_loss: 0.0000e+00 - learning_rate: 5.0000e-04
# Epoch 19/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0674 - val_loss: 0.0000e+00 - learning_rate: 5.0000e-04
# Epoch 20/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0663 - val_loss: 0.0000e+00 - learning_rate: 5.0000e-04
# Epoch 21/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0652 - val_loss: 0.0000e+00 - learning_rate: 5.0000e-04
# Epoch 22/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0636 - val_loss: 0.0000e+00 - learning_rate: 5.0000e-04
# Epoch 23/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0632 - val_loss: 0.0000e+00 - learning_rate: 5.0000e-04
# Epoch 24/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0623 - val_loss: 0.0000e+00 - learning_rate: 5.0000e-04
# Epoch 25/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0605 - val_loss: 0.0000e+00 - learning_rate: 5.0000e-04
# Epoch 26/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0599 - val_loss: 0.0000e+00 - learning_rate: 5.0000e-04
# Epoch 27/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0592 - val_loss: 0.0000e+00 - learning_rate: 5.0000e-04
# Epoch 28/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0580 - val_loss: 0.0000e+00 - learning_rate: 5.0000e-04
# Epoch 29/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0576 - val_loss: 0.0000e+00 - learning_rate: 5.0000e-04
# Epoch 30/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0560 - val_loss: 0.0000e+00 - learning_rate: 5.0000e-04
# Epoch 31/100
# 68/71 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0567
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0557 - val_loss: 0.0000e+00 - learning_rate: 5.0000e-04
# Epoch 31: early stopping
# Restoring model weights from the end of the best epoch: 1.
# Imputing missing values...
# Imputing missing values using trained autoencoder...
# Imputed 3382.0 missing values
# Imputing missing values using trained autoencoder...
# Imputed 857.0 missing values
# Imputing missing values using trained autoencoder...
# Imputed 1815.0 missing values
#
# ======================================================================
# STAGE 2: LSTM Survival Prediction
# ======================================================================
#
# Sequence shapes:
#   Training sequences: (1503, 3, 68), labels: (1503, 2)
#   Validation sequences: (376, 3, 68), labels: (376, 2)
#   Test sequences: (805, 3, 68), labels: (805, 2)
#
# Training LSTM Autoencoder for feature extraction...
# LSTM Autoencoder architecture:
# Model: "functional_27"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_23 (InputLayer)     │ (None, 3, 68)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_25 (LSTM)                  │ (None, 3, 64)          │        34,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_26 (LSTM)                  │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ repeat_vector_4 (RepeatVector)  │ (None, 3, 32)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_27 (LSTM)                  │ (None, 3, 32)          │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_28 (LSTM)                  │ (None, 3, 64)          │        24,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_13             │ (None, 3, 68)          │         4,420 │
# │ (TimeDistributed)               │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 84,036 (328.27 KB)
#  Trainable params: 84,036 (328.27 KB)
#  Non-trainable params: 0 (0.00 B)
# None
# Training LSTM autoencoder...
# Epoch 1/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 9s 97ms/step - loss: 2.3878 - mae: 0.4646 - val_loss: 1.7387 - val_mae: 0.4260 - learning_rate: 0.0010
# Epoch 2/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6011 - mae: 0.4136 - val_loss: 1.4597 - val_mae: 0.3951 - learning_rate: 0.0010
# Epoch 3/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.4225 - mae: 0.3939 - val_loss: 1.4064 - val_mae: 0.3904 - learning_rate: 0.0010
# Epoch 4/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.3755 - mae: 0.3883 - val_loss: 1.3686 - val_mae: 0.3843 - learning_rate: 0.0010
# Epoch 5/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.3403 - mae: 0.3839 - val_loss: 1.3329 - val_mae: 0.3810 - learning_rate: 0.0010
# Epoch 6/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.2929 - mae: 0.3801 - val_loss: 1.2536 - val_mae: 0.3733 - learning_rate: 0.0010
# Epoch 7/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.2195 - mae: 0.3715 - val_loss: 1.1951 - val_mae: 0.3681 - learning_rate: 0.0010
# Epoch 8/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1685 - mae: 0.3671 - val_loss: 1.1309 - val_mae: 0.3605 - learning_rate: 0.0010
# Epoch 9/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0938 - mae: 0.3576 - val_loss: 1.0677 - val_mae: 0.3531 - learning_rate: 0.0010
# Epoch 10/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0293 - mae: 0.3485 - val_loss: 1.0100 - val_mae: 0.3462 - learning_rate: 0.0010
# Epoch 11/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9759 - mae: 0.3428 - val_loss: 0.9521 - val_mae: 0.3422 - learning_rate: 0.0010
# Epoch 12/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9140 - mae: 0.3357 - val_loss: 0.8792 - val_mae: 0.3314 - learning_rate: 0.0010
# Epoch 13/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.8414 - mae: 0.3258 - val_loss: 0.8106 - val_mae: 0.3261 - learning_rate: 0.0010
# Epoch 14/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.7693 - mae: 0.3170 - val_loss: 0.7327 - val_mae: 0.3128 - learning_rate: 0.0010
# Epoch 15/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.6934 - mae: 0.3079 - val_loss: 0.6637 - val_mae: 0.3058 - learning_rate: 0.0010
# Epoch 16/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.6327 - mae: 0.2993 - val_loss: 0.6268 - val_mae: 0.3002 - learning_rate: 0.0010
# Epoch 17/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5798 - mae: 0.2904 - val_loss: 0.5878 - val_mae: 0.2921 - learning_rate: 0.0010
# Epoch 18/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.5406 - mae: 0.2816 - val_loss: 0.5606 - val_mae: 0.2871 - learning_rate: 0.0010
# Epoch 19/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5144 - mae: 0.2763 - val_loss: 0.5296 - val_mae: 0.2797 - learning_rate: 0.0010
# Epoch 20/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.4945 - mae: 0.2722 - val_loss: 0.5062 - val_mae: 0.2743 - learning_rate: 0.0010
# Epoch 21/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.4664 - mae: 0.2661 - val_loss: 0.4810 - val_mae: 0.2708 - learning_rate: 0.0010
# Epoch 22/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.4422 - mae: 0.2617 - val_loss: 0.4559 - val_mae: 0.2674 - learning_rate: 0.0010
# Epoch 23/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.4179 - mae: 0.2576 - val_loss: 0.4325 - val_mae: 0.2634 - learning_rate: 0.0010
# Epoch 24/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.3968 - mae: 0.2536 - val_loss: 0.4122 - val_mae: 0.2590 - learning_rate: 0.0010
# Epoch 25/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.3774 - mae: 0.2498 - val_loss: 0.3932 - val_mae: 0.2540 - learning_rate: 0.0010
# Epoch 26/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.3607 - mae: 0.2466 - val_loss: 0.3774 - val_mae: 0.2509 - learning_rate: 0.0010
# Epoch 27/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.3455 - mae: 0.2437 - val_loss: 0.3674 - val_mae: 0.2480 - learning_rate: 0.0010
# Epoch 28/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.3326 - mae: 0.2409 - val_loss: 0.3559 - val_mae: 0.2461 - learning_rate: 0.0010
# Epoch 29/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.3205 - mae: 0.2381 - val_loss: 0.3436 - val_mae: 0.2434 - learning_rate: 0.0010
# Epoch 30/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.3104 - mae: 0.2357 - val_loss: 0.3380 - val_mae: 0.2426 - learning_rate: 0.0010
# Epoch 31/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.3032 - mae: 0.2339 - val_loss: 0.3384 - val_mae: 0.2423 - learning_rate: 0.0010
# Epoch 32/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3006 - mae: 0.2331 - val_loss: 0.3253 - val_mae: 0.2383 - learning_rate: 0.0010
# Epoch 33/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2911 - mae: 0.2308 - val_loss: 0.3221 - val_mae: 0.2368 - learning_rate: 0.0010
# Epoch 34/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2836 - mae: 0.2284 - val_loss: 0.3148 - val_mae: 0.2349 - learning_rate: 0.0010
# Epoch 35/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2774 - mae: 0.2261 - val_loss: 0.3061 - val_mae: 0.2323 - learning_rate: 0.0010
# Epoch 36/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.2707 - mae: 0.2240 - val_loss: 0.3005 - val_mae: 0.2299 - learning_rate: 0.0010
# Epoch 37/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.2668 - mae: 0.2227 - val_loss: 0.2995 - val_mae: 0.2291 - learning_rate: 0.0010
# Epoch 38/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2633 - mae: 0.2217 - val_loss: 0.3013 - val_mae: 0.2300 - learning_rate: 0.0010
# Epoch 39/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2606 - mae: 0.2207 - val_loss: 0.2889 - val_mae: 0.2266 - learning_rate: 0.0010
# Epoch 40/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2566 - mae: 0.2194 - val_loss: 0.2852 - val_mae: 0.2254 - learning_rate: 0.0010
# Epoch 41/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2527 - mae: 0.2183 - val_loss: 0.2866 - val_mae: 0.2238 - learning_rate: 0.0010
# Epoch 42/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.2489 - mae: 0.2167 - val_loss: 0.2871 - val_mae: 0.2232 - learning_rate: 0.0010
# Epoch 43/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2451 - mae: 0.2153 - val_loss: 0.2837 - val_mae: 0.2220 - learning_rate: 0.0010
# Epoch 44/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.2412 - mae: 0.2136 - val_loss: 0.2789 - val_mae: 0.2205 - learning_rate: 0.0010
# Epoch 45/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.2372 - mae: 0.2120 - val_loss: 0.2755 - val_mae: 0.2192 - learning_rate: 0.0010
# Epoch 46/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.2340 - mae: 0.2105 - val_loss: 0.2735 - val_mae: 0.2182 - learning_rate: 0.0010
# Epoch 47/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2314 - mae: 0.2093 - val_loss: 0.2715 - val_mae: 0.2174 - learning_rate: 0.0010
# Epoch 48/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2292 - mae: 0.2083 - val_loss: 0.2721 - val_mae: 0.2168 - learning_rate: 0.0010
# Epoch 49/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2273 - mae: 0.2072 - val_loss: 0.2655 - val_mae: 0.2153 - learning_rate: 0.0010
# Epoch 50/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.2254 - mae: 0.2064 - val_loss: 0.2645 - val_mae: 0.2144 - learning_rate: 0.0010
# Epoch 51/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2230 - mae: 0.2053 - val_loss: 0.2592 - val_mae: 0.2134 - learning_rate: 0.0010
# Epoch 52/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.2205 - mae: 0.2042 - val_loss: 0.2600 - val_mae: 0.2125 - learning_rate: 0.0010
# Epoch 53/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.2184 - mae: 0.2031 - val_loss: 0.2570 - val_mae: 0.2118 - learning_rate: 0.0010
# Epoch 54/80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.
80
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1762 - mae: 0.1829 - val_loss: 0.2055 - val_mae: 0.1928 - learning_rate: 0.0010
# Extracting encoded features...
#
# Training Survival LSTM...
# Survival LSTM architecture:
# Model: "functional_29"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_24      │ (None, 1, 32)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional_9     │ (None, 1, 128)    │     49,664 │ input_layer_24[0… │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_18          │ (None, 1, 128)    │          0 │ bidirectional_9[… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ time_distributed_14 │ (None, 1, 1)      │        129 │ dropout_18[0][0]  │
# │ (TimeDistributed)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ softmax_9 (Softmax) │ (None, 1, 1)      │          0 │ time_distributed… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_9          │ (None, 1, 128)    │          0 │ dropout_18[0][0], │
# │ (Multiply)          │                   │            │ softmax_9[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_9 (Lambda)   │ (None, 128)       │          0 │ multiply_9[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_93 (Dense)    │ (None, 64)        │      8,256 │ lambda_9[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64)        │        256 │ dense_93[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_19          │ (None, 64)        │          0 │ batch_normalizat… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_94 (Dense)    │ (None, 32)        │      2,080 │ dropout_19[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32)        │        128 │ dense_94[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ survival_time       │ (None, 1)         │         33 │ batch_normalizat… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ event (Dense)       │ (None, 1)         │         33 │ batch_normalizat… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 60,579 (236.64 KB)
#  Trainable params: 60,387 (235.89 KB)
#  Non-trainable params: 192 (768.00 B)
# None
# Training Survival LSTM...
# Epoch 1/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 7s 26ms/step - event_accuracy: 0.4922 - event_auc_9: 0.5121 - event_loss: 0.8793 - loss: 18669.8672 - survival_time_loss: 31116.4395 - survival_time_mae: 132.9869 - survival_time_root_mean_squared_error: 176.2114 - val_event_accuracy: 0.1995 - val_event_auc_9: 0.5004 - val_event_loss: 0.7516 - val_loss: 19963.9375 - val_survival_time_loss: 33617.3438 - val_survival_time_mae: 133.7924 - val_survival_time_root_mean_squared_error: 182.4081 - learning_rate: 5.0000e-04
# Epoch 2/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - event_accuracy: 0.4460 - event_auc_9: 0.4776 - event_loss: 0.8913 - loss: 18396.7832 - survival_time_loss: 30661.2871 - survival_time_mae: 131.5999 - survival_time_root_mean_squared_error: 174.9159 - val_event_accuracy: 0.2979 - val_event_auc_9: 0.4891 - val_event_loss: 0.7447 - val_loss: 19815.7012 - val_survival_time_loss: 33371.4414 - val_survival_time_mae: 133.0287 - val_survival_time_root_mean_squared_error: 181.7297 - learning_rate: 5.0000e-04
# Epoch 3/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - event_accuracy: 0.4869 - event_auc_9: 0.5050 - event_loss: 0.7820 - loss: 18190.9258 - survival_time_loss: 30318.2617 - survival_time_mae: 130.5921 - survival_time_root_mean_squared_error: 173.9306 - val_event_accuracy: 0.3404 - val_event_auc_9: 0.4659 - val_event_loss: 0.7069 - val_loss: 19659.7461 - val_survival_time_loss: 33112.0664 - val_survival_time_mae: 132.2480 - val_survival_time_root_mean_squared_error: 181.0132 - learning_rate: 5.0000e-04
# Epoch 4/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - event_accuracy: 0.5293 - event_auc_9: 0.5085 - event_loss: 0.7143 - loss: 18010.0273 - survival_time_loss: 30016.8105 - survival_time_mae: 129.7456 - survival_time_root_mean_squared_error: 173.0623 - val_event_accuracy: 0.7447 - val_event_auc_9: 0.4633 - val_event_loss: 0.6715 - val_loss: 19506.1562 - val_survival_time_loss: 32856.5508 - val_survival_time_mae: 131.5240 - val_survival_time_root_mean_squared_error: 180.3048 - learning_rate: 5.0000e-04
# Epoch 5/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - event_accuracy: 0.5510 - event_auc_9: 0.4991 - event_loss: 0.6881 - loss: 17834.1816 - survival_time_loss: 29723.7520 - survival_time_mae: 128.9452 - survival_time_root_mean_squared_error: 172.2123 - val_event_accuracy: 0.6543 - val_event_auc_9: 0.5002 - val_event_loss: 0.6695 - val_loss: 19395.0527 - val_survival_time_loss: 32671.1973 - val_survival_time_mae: 131.2124 - val_survival_time_root_mean_squared_error: 179.7905 - learning_rate: 5.0000e-04
# Epoch 6/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - event_accuracy: 0.6071 - event_auc_9: 0.5343 - event_loss: 0.6703 - loss: 17620.5527 - survival_time_loss: 29367.7188 - survival_time_mae: 128.1630 - survival_time_root_mean_squared_error: 171.1770 - val_event_accuracy: 0.6170 - val_event_auc_9: 0.5056 - val_event_loss: 0.6773 - val_loss: 19353.3828 - val_survival_time_loss: 32600.3105 - val_survival_time_mae: 131.5286 - val_survival_time_root_mean_squared_error: 179.5973 - learning_rate: 5.0000e-04
# Epoch 7/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - event_accuracy: 0.6207 - event_auc_9: 0.5124 - event_loss: 0.6692 - loss: 17361.0391 - survival_time_loss: 28935.1875 - survival_time_mae: 127.3526 - survival_time_root_mean_squared_error: 169.9095 - val_event_accuracy: 0.6383 - val_event_auc_9: 0.5101 - val_event_loss: 0.6590 - val_loss: 19142.5312 - val_survival_time_loss: 32248.1270 - val_survival_time_mae: 130.8569 - val_survival_time_root_mean_squared_error: 178.6163 - learning_rate: 5.0000e-04
# Epoch 8/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - event_accuracy: 0.5953 - event_auc_9: 0.4620 - event_loss: 0.6689 - loss: 17071.4629 - survival_time_loss: 28452.5605 - survival_time_mae: 126.3526 - survival_time_root_mean_squared_error: 168.4807 - val_event_accuracy: 0.7766 - val_event_auc_9: 0.5393 - val_event_loss: 0.6136 - val_loss: 18698.0078 - val_survival_time_loss: 31506.1484 - val_survival_time_mae: 129.1116 - val_survival_time_root_mean_squared_error: 176.5303 - learning_rate: 5.0000e-04
# Epoch 9/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - event_accuracy: 0.6195 - event_auc_9: 0.5063 - event_loss: 0.6399 - loss: 16823.6621 - survival_time_loss: 28039.5781 - survival_time_mae: 125.2567 - survival_time_root_mean_squared_error: 167.2524 - val_event_accuracy: 0.7553 - val_event_auc_9: 0.5628 - val_event_loss: 0.6111 - val_loss: 18467.5234 - val_survival_time_loss: 31119.9199 - val_survival_time_mae: 128.3391 - val_survival_time_root_mean_squared_error: 175.4389 - learning_rate: 5.0000e-04
# Epoch 10/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - event_accuracy: 0.6458 - event_auc_9: 0.5290 - event_loss: 0.6296 - loss: 16547.2949 - survival_time_loss: 27578.9766 - survival_time_mae: 124.3010 - survival_time_root_mean_squared_error: 165.8682 - val_event_accuracy: 0.7926 - val_event_auc_9: 0.5662 - val_event_loss: 0.5931 - val_loss: 18052.3730 - val_survival_time_loss: 30427.5938 - val_survival_time_mae: 126.6726 - val_survival_time_root_mean_squared_error: 173.4557 - learning_rate: 5.0000e-04
# Epoch 11/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - event_accuracy: 0.6599 - event_auc_9: 0.5128 - event_loss: 0.6205 - loss: 16304.3691 - survival_time_loss: 27174.1055 - survival_time_mae: 123.1223 - survival_time_root_mean_squared_error: 164.6458 - val_event_accuracy: 0.7394 - val_event_auc_9: 0.5720 - val_event_loss: 0.6015 - val_loss: 17620.9570 - val_survival_time_loss: 29707.9824 - val_survival_time_mae: 125.0070 - val_survival_time_root_mean_squared_error: 171.3705 - learning_rate: 5.0000e-04
# Epoch 12/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - event_accuracy: 0.6680 - event_auc_9: 0.4748 - event_loss: 0.6214 - loss: 16041.6348 - survival_time_loss: 26736.2090 - survival_time_mae: 122.0248 - survival_time_root_mean_squared_error: 163.3114 - val_event_accuracy: 0.7819 - val_event_auc_9: 0.5792 - val_event_loss: 0.5813 - val_loss: 17160.7930 - val_survival_time_loss: 28941.1094 - val_survival_time_mae: 123.1861 - val_survival_time_root_mean_squared_error: 169.1181 - learning_rate: 5.0000e-04
# Epoch 13/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - event_accuracy: 0.6926 - event_auc_9: 0.5308 - event_loss: 0.5991 - loss: 15763.2861 - survival_time_loss: 26272.3086 - survival_time_mae: 120.8657 - survival_time_root_mean_squared_error: 161.8781 - val_event_accuracy: 0.7447 - val_event_auc_9: 0.5509 - val_event_loss: 0.5779 - val_loss: 16636.1445 - val_survival_time_loss: 28067.5371 - val_survival_time_mae: 120.8030 - val_survival_time_root_mean_squared_error: 166.5128 - learning_rate: 5.0000e-04
# Epoch 14/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - event_accuracy: 0.7179 - event_auc_9: 0.5239 - event_loss: 0.5926 - loss: 15476.7529 - survival_time_loss: 25794.7480 - survival_time_mae: 119.5781 - survival_time_root_mean_squared_error: 160.3997 - val_event_accuracy: 0.7473 - val_event_auc_9: 0.5289 - val_event_loss: 0.5672 - val_loss: 16066.4697 - val_survival_time_loss: 27104.7324 - val_survival_time_mae: 118.2628 - val_survival_time_root_mean_squared_error: 163.6370 - learning_rate: 5.0000e-04
# Epoch 15/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - event_accuracy: 0.6961 - event_auc_9: 0.4887 - event_loss: 0.5907 - loss: 15138.5586 - survival_time_loss: 25231.0664 - survival_time_mae: 118.3978 - survival_time_root_mean_squared_error: 158.6272 - val_event_accuracy: 0.7899 - val_event_auc_9: 0.5616 - val_event_loss: 0.5554 - val_loss: 15860.5957 - val_survival_time_loss: 26751.9395 - val_survival_time_mae: 117.3646 - val_survival_time_root_mean_squared_error: 162.5852 - learning_rate: 5.0000e-04
# Epoch 16/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - event_accuracy: 0.7244 - event_auc_9: 0.5304 - event_loss: 0.5722 - loss: 14775.1543 - survival_time_loss: 24625.4180 - survival_time_mae: 116.5712 - survival_time_root_mean_squared_error: 156.7177 - val_event_accuracy: 0.7926 - val_event_auc_9: 0.5548 - val_event_loss: 0.5266 - val_loss: 14783.8125 - val_survival_time_loss: 24916.0254 - val_survival_time_mae: 111.7354 - val_survival_time_root_mean_squared_error: 156.9692 - learning_rate: 5.0000e-04
# Epoch 17/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - event_accuracy: 0.7271 - event_auc_9: 0.5170 - event_loss: 0.5693 - loss: 14463.3281 - survival_time_loss: 24105.6895 - survival_time_mae: 114.6580 - survival_time_root_mean_squared_error: 155.0390 - val_event_accuracy: 0.8351 - val_event_auc_9: 0.5701 - val_event_loss: 0.5301 - val_loss: 14730.5186 - val_survival_time_loss: 24833.9902 - val_survival_time_mae: 111.9796 - val_survival_time_root_mean_squared_error: 156.6860 - learning_rate: 5.0000e-04
# Epoch 18/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - event_accuracy: 0.7151 - event_auc_9: 0.4909 - event_loss: 0.5647 - loss: 14039.7285 - survival_time_loss: 23399.7012 - survival_time_mae: 113.0863 - survival_time_root_mean_squared_error: 152.7483 - val_event_accuracy: 0.8245 - val_event_auc_9: 0.5542 - val_event_loss: 0.5358 - val_loss: 14342.0840 - val_survival_time_loss: 24168.7559 - val_survival_time_mae: 110.5063 - val_survival_time_root_mean_squared_error: 154.6063 - learning_rate: 5.0000e-04
# Epoch 19/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - event_accuracy: 0.7334 - event_auc_9: 0.5097 - event_loss: 0.5557 - loss: 13747.9697 - survival_time_loss: 22913.4316 - survival_time_mae: 111.4256 - survival_time_root_mean_squared_error: 151.1471 - val_event_accuracy: 0.8351 - val_event_auc_9: 0.5753 - val_event_loss: 0.5343 - val_loss: 14237.6514 - val_survival_time_loss: 24002.2969 - val_survival_time_mae: 109.9693 - val_survival_time_root_mean_squared_error: 154.0424 - learning_rate: 5.0000e-04
# Epoch 20/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - event_accuracy: 0.7714 - event_auc_9: 0.5327 - event_loss: 0.5438 - loss: 13386.5684 - survival_time_loss: 22311.0723 - survival_time_mae: 109.7407 - survival_time_root_mean_squared_error: 149.1535 - val_event_accuracy: 0.8059 - val_event_auc_9: 0.5559 - val_event_loss: 0.5219 - val_loss: 13669.6729 - val_survival_time_loss: 23049.9863 - val_survival_time_mae: 107.2000 - val_survival_time_root_mean_squared_error: 150.9385 - learning_rate: 5.0000e-04
# Epoch 21/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - event_accuracy: 0.7486 - event_auc_9: 0.5189 - event_loss: 0.5406 - loss: 12991.7744 - survival_time_loss: 21653.0762 - survival_time_mae: 108.1458 - survival_time_root_mean_squared_error: 146.9191 - val_event_accuracy: 0.7819 - val_event_auc_9: 0.5434 - val_event_loss: 0.5148 - val_loss: 12939.8936 - val_survival_time_loss: 21834.5195 - val_survival_time_mae: 102.9376 - val_survival_time_root_mean_squared_error: 146.8542 - learning_rate: 5.0000e-04
# Epoch 22/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - event_accuracy: 0.7637 - event_auc_9: 0.5058 - event_loss: 0.5402 - loss: 12684.2598 - survival_time_loss: 21140.5332 - survival_time_mae: 106.4097 - survival_time_root_mean_squared_error: 145.1739 - val_event_accuracy: 0.8564 - val_event_auc_9: 0.5523 - val_event_loss: 0.5084 - val_loss: 12942.2715 - val_survival_time_loss: 21835.9062 - val_survival_time_mae: 103.6767 - val_survival_time_root_mean_squared_error: 146.8676 - learning_rate: 5.0000e-04
# Epoch 23/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - event_accuracy: 0.7749 - event_auc_9: 0.5276 - event_loss: 0.5258 - loss: 12364.1055 - survival_time_loss: 20606.9590 - survival_time_mae: 104.8342 - survival_time_root_mean_squared_error: 143.3304 - val_event_accuracy: 0.8511 - val_event_auc_9: 0.5552 - val_event_loss: 0.5289 - val_loss: 13196.3408 - val_survival_time_loss: 22262.0684 - val_survival_time_mae: 105.2468 - val_survival_time_root_mean_squared_error: 148.3022 - learning_rate: 5.0000e-04
# Epoch 24/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - event_accuracy: 0.7974 - event_auc_9: 0.5402 - event_loss: 0.5178 - loss: 11992.3750 - survival_time_loss: 19987.4043 - survival_time_mae: 103.0407 - survival_time_root_mean_squared_error: 141.1438 - val_event_accuracy: 0.8564 - val_event_auc_9: 0.5602 - val_event_loss: 0.5071 - val_loss: 12371.1865 - val_survival_time_loss: 20872.9609 - val_survival_time_mae: 101.1581 - val_survival_time_root_mean_squared_error: 143.5907 - learning_rate: 5.0000e-04
# Epoch 25/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - event_accuracy: 0.7922 - event_auc_9: 0.5159 - event_loss: 0.5177 - loss: 11566.5566 - survival_time_loss: 19277.7070 - survival_time_mae: 101.1179 - survival_time_root_mean_squared_error: 138.5924 - val_event_accuracy: 0.8431 - val_event_auc_9: 0.5512 - val_event_loss: 0.5068 - val_loss: 11955.8340 - val_survival_time_loss: 20185.3887 - val_survival_time_mae: 98.6485 - val_survival_time_root_mean_squared_error: 141.1597 - learning_rate: 5.0000e-04
# Epoch 26/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - event_accuracy: 0.8104 - event_auc_9: 0.5024 - event_loss: 0.5149 - loss: 11242.8838 - survival_time_loss: 18738.2578 - survival_time_mae: 99.1410 - survival_time_root_mean_squared_error: 136.6399 - val_event_accuracy: 0.8590 - val_event_auc_9: 0.5496 - val_event_loss: 0.5044 - val_loss: 11793.1279 - val_survival_time_loss: 19911.8340 - val_survival_time_mae: 98.1910 - val_survival_time_root_mean_squared_error: 140.1958 - learning_rate: 5.0000e-04
# Epoch 27/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - event_accuracy: 0.8256 - event_auc_9: 0.5313 - event_loss: 0.5030 - loss: 10990.6133 - survival_time_loss: 18317.7832 - survival_time_mae: 97.9880 - survival_time_root_mean_squared_error: 135.1176 - val_event_accuracy: 0.8617 - val_event_auc_9: 0.5482 - val_event_loss: 0.4988 - val_loss: 11502.1182 - val_survival_time_loss: 19441.2285 - val_survival_time_mae: 96.6206 - val_survival_time_root_mean_squared_error: 138.4553 - learning_rate: 5.0000e-04
# Epoch 28/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - event_accuracy: 0.8251 - event_auc_9: 0.5165 - event_loss: 0.5042 - loss: 10631.6641 - survival_time_loss: 17719.5195 - survival_time_mae: 96.1891 - survival_time_root_mean_squared_error: 132.8653 - val_event_accuracy: 0.8617 - val_event_auc_9: 0.5544 - val_event_loss: 0.4903 - val_loss: 11224.1328 - val_survival_time_loss: 18968.4668 - val_survival_time_mae: 95.4025 - val_survival_time_root_mean_squared_error: 136.7719 - learning_rate: 5.0000e-04
# Epoch 29/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - event_accuracy: 0.8043 - event_auc_9: 0.4949 - event_loss: 0.5040 - loss: 10298.2070 - survival_time_loss: 17163.7578 - survival_time_mae: 94.2528 - survival_time_root_mean_squared_error: 130.7632 - val_event_accuracy: 0.8617 - val_event_auc_9: 0.5572 - val_event_loss: 0.4796 - val_loss: 10591.3301 - val_survival_time_loss: 17911.2285 - val_survival_time_mae: 92.2101 - val_survival_time_root_mean_squared_error: 132.8604 - learning_rate: 5.0000e-04
# Epoch 30/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - event_accuracy: 0.8324 - event_auc_9: 0.4975 - event_loss: 0.4976 - loss: 9922.6006 - survival_time_loss: 16537.7129 - survival_time_mae: 92.5825 - survival_time_root_mean_squared_error: 128.3412 - val_event_accuracy: 0.8617 - val_event_auc_9: 0.5533 - val_event_loss: 0.4877 - val_loss: 10567.1104 - val_survival_time_loss: 17831.6484 - val_survival_time_mae: 93.5032 - val_survival_time_root_mean_squared_error: 132.7084 - learning_rate: 5.0000e-04
# Epoch 31/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - event_accuracy: 0.8264 - event_auc_9: 0.5327 - event_loss: 0.4869 - loss: 9597.6084 - survival_time_loss: 15996.0811 - survival_time_mae: 90.7365 - survival_time_root_mean_squared_error: 126.2073 - val_event_accuracy: 0.8617 - val_event_auc_9: 0.5564 - val_event_loss: 0.4642 - val_loss: 9360.7803 - val_survival_time_loss: 15820.3281 - val_survival_time_mae: 85.3435 - val_survival_time_root_mean_squared_error: 124.9039 - learning_rate: 5.0000e-04
# Epoch 32/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - event_accuracy: 0.8446 - event_auc_9: 0.5295 - event_loss: 0.4831 - loss: 9308.1289 - survival_time_loss: 15513.6250 - survival_time_mae: 89.1585 - survival_time_root_mean_squared_error: 124.2869 - val_event_accuracy: 0.8617 - val_event_auc_9: 0.5539 - val_event_loss: 0.4773 - val_loss: 9702.8213 - val_survival_time_loss: 16405.8086 - val_survival_time_mae: 87.7423 - val_survival_time_root_mean_squared_error: 127.1654 - learning_rate: 5.0000e-04
# Epoch 33/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - event_accuracy: 0.8511 - event_auc_9: 0.5191 - event_loss: 0.4842 - loss: 9022.8096 - survival_time_loss: 15038.0850 - survival_time_mae: 87.7000 - survival_time_root_mean_squared_error: 122.3825 - val_event_accuracy: 0.8617 - val_event_auc_9: 0.5489 - val_event_loss: 0.4799 - val_loss: 9743.9219 - val_survival_time_loss: 16491.8848 - val_survival_time_mae: 88.5741 - val_survival_time_root_mean_squared_error: 127.4345 - learning_rate: 5.0000e-04
# Epoch 34/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - event_accuracy: 0.8497 - event_auc_9: 0.5347 - event_loss: 0.4749 - loss: 8789.4395 - survival_time_loss: 14649.1250 - survival_time_mae: 86.3404 - survival_time_root_mean_squared_error: 120.7407 - val_event_accuracy: 0.8617 - val_event_auc_9: 0.5524 - val_event_loss: 0.4741 - val_loss: 9099.3682 - val_survival_time_loss: 15386.8164 - val_survival_time_mae: 84.8582 - val_survival_time_root_mean_squared_error: 123.1474 - learning_rate: 5.0000e-04
# Epoch 35/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - event_accuracy: 0.8482 - event_auc_9: 0.5328 - event_loss: 0.4726 - loss: 8476.3467 - survival_time_loss: 14127.2627 - survival_time_mae: 85.0159 - survival_time_root_mean_squared_error: 118.5683 - val_event_accuracy: 0.8617 - val_event_auc_9: 0.5552 - val_event_loss: 0.4642 - val_loss: 8346.6504 - val_survival_time_loss: 14124.2373 - val_survival_time_mae: 80.2233 - val_survival_time_root_mean_squared_error: 117.9439 - learning_rate: 5.0000e-04
# Epoch 36/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - event_accuracy: 0.8575 - event_auc_9: 0.5417 - event_loss: 0.4658 - loss: 8078.9912 - survival_time_loss: 13465.0273 - survival_time_mae: 82.6587 - survival_time_root_mean_squared_error: 115.7453 - val_event_accuracy: 0.8617 - val_event_auc_9: 0.5468 - val_event_loss: 0.4667 - val_loss: 8466.1113 - val_survival_time_loss: 14332.6396 - val_survival_time_mae: 81.5222 - val_survival_time_root_mean_squared_error: 118.7850 - learning_rate: 5.0000e-04
# Epoch 37/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - event_accuracy: 0.8519 - event_auc_9: 0.5472 - event_loss: 0.4633 - loss: 7873.0693 - survival_time_loss: 13121.8564 - survival_time_mae: 81.0922 - survival_time_root_mean_squared_error: 114.1829 - val_event_accuracy: 0.8617 - val_event_auc_9: 0.5441 - val_event_loss: 0.4599 - val_loss: 7778.7964 - val_survival_time_loss: 13186.5615 - val_survival_time_mae: 76.2880 - val_survival_time_root_mean_squared_error: 113.8611 - learning_rate: 5.0000e-04
# Epoch 38/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - event_accuracy: 0.8659 - event_auc_9: 0.5462 - event_loss: 0.4578 - loss: 7570.3188 - survival_time_loss: 12617.2441 - survival_time_mae: 79.8334 - survival_time_root_mean_squared_error: 112.0013 - val_event_accuracy: 0.8617 - val_event_auc_9: 0.5380 - val_event_loss: 0.4630 - val_loss: 7813.8120 - val_survival_time_loss: 13237.3057 - val_survival_time_mae: 77.7987 - val_survival_time_root_mean_squared_error: 114.1171 - learning_rate: 5.0000e-04
# Epoch 39/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - event_accuracy: 0.8634 - event_auc_9: 0.5126 - event_loss: 0.4634 - loss: 7413.8418 - survival_time_loss: 12356.4141 - survival_time_mae: 78.9680 - survival_time_root_mean_squared_error: 110.8874 - val_event_accuracy: 0.8617 - val_event_auc_9: 0.5438 - val_event_loss: 0.4537 - val_loss: 7454.0718 - val_survival_time_loss: 12625.7939 - val_survival_time_mae: 75.7276 - val_survival_time_root_mean_squared_error: 111.4592 - learning_rate: 5.0000e-04
# Epoch 40/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - event_accuracy: 0.8660 - event_auc_9: 0.5360 - event_loss: 0.4560 - loss: 7096.0640 - survival_time_loss: 11826.7979 - survival_time_mae: 76.7877 - survival_time_root_mean_squared_error: 108.4253 - val_event_accuracy: 0.8617 - val_event_auc_9: 0.5498 - val_event_loss: 0.4546 - val_loss: 7505.0527 - val_survival_time_loss: 12704.6045 - val_survival_time_mae: 76.6168 - val_survival_time_root_mean_squared_error: 111.8397 - learning_rate: 5.0000e-04
# Epoch 41/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - event_accuracy: 0.8640 - event_auc_9: 0.5318 - event_loss: 0.4554 - loss: 6962.2803 - survival_time_loss: 11603.8057 - survival_time_mae: 75.9848 - survival_time_root_mean_squared_error: 107.4152 - val_event_accuracy: 0.8617 - val_event_auc_9: 0.5585 - val_event_loss: 0.4476 - val_loss: 7066.9575 - val_survival_time_loss: 11958.9961 - val_survival_time_mae: 74.5334 - val_survival_time_root_mean_squared_error: 108.5263 - learning_rate: 5.0000e-04
# Epoch 42/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - event_accuracy: 0.8683 - event_auc_9: 0.5368 - event_loss: 0.4520 - loss: 6772.5806 - survival_time_loss: 11287.6846 - survival_time_mae: 75.5881 - survival_time_root_mean_squared_error: 105.9212 - val_event_accuracy: 0.8617 - val_event_auc_9: 0.5504 - val_event_loss: 0.4461 - val_loss: 6494.1484 - val_survival_time_loss: 11020.9150 - val_survival_time_mae: 70.4865 - val_survival_time_root_mean_squared_error: 104.0350 - learning_rate: 5.0000e-04
# Epoch 43/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - event_accuracy: 0.8679 - event_auc_9: 0.5392 - event_loss: 0.4483 - loss: 6552.5801 - survival_time_loss: 10920.9297 - survival_time_mae: 73.5557 - survival_time_root_mean_squared_error: 104.1533 - val_event_accuracy: 0.8617 - val_event_auc_9: 0.5493 - val_event_loss: 0.4449 - val_loss: 6469.3662 - val_survival_time_loss: 10964.7070 - val_survival_time_mae: 70.5775 - val_survival_time_root_mean_squared_error: 103.8363 - learning_rate: 5.0000e-04
# Epoch 44/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - event_accuracy: 0.8681 - event_auc_9: 0.5415 - event_loss: 0.4454 - loss: 6333.8472 - survival_time_loss: 10556.4277 - survival_time_mae: 72.4145 - survival_time_root_mean_squared_error: 102.4406 - val_event_accuracy: 0.8617 - val_event_auc_9: 0.5555 - val_event_loss: 0.4419 - val_loss: 6189.9121 - val_survival_time_loss: 10512.9521 - val_survival_time_mae: 68.3952 - val_survival_time_root_mean_squared_error: 101.5688 - learning_rate: 5.0000e-04
# Epoch 45/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - event_accuracy: 0.8681 - event_auc_9: 0.5230 - event_loss: 0.4480 - loss: 6071.9731 - survival_time_loss: 10119.9463 - survival_time_mae: 70.6943 - survival_time_root_mean_squared_error: 100.2483 - val_event_accuracy: 0.8617 - val_event_auc_9: 0.5477 - val_event_loss: 0.4485 - val_loss: 6464.5420 - val_survival_time_loss: 10970.1123 - val_survival_time_mae: 70.7701 - val_survival_time_root_mean_squared_error: 103.7976 - learning_rate: 5.0000e-04
# Epoch 46/120
# ...
# Epoch 91/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - event_accuracy: 0.8679 - event_auc_9: 0.5382 - event_loss: 0.4032 - loss: 3568.2148 - survival_time_loss: 5946.8730 - survival_time_mae: 56.7080 - survival_time_root_mean_squared_error: 76.9520 - val_event_accuracy: 0.8617 - val_event_auc_9: 0.5622 - val_event_loss: 0.4028 - val_loss: 3572.1240 - val_survival_time_loss: 6076.4805 - val_survival_time_mae: 52.6100 - val_survival_time_root_mean_squared_error: 77.1574 - learning_rate: 5.0000e-04
# Epoch 92/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - event_accuracy: 0.8698 - event_auc_9: 0.5242 - event_loss: 0.4046 - loss: 3562.1431 - survival_time_loss: 5936.8232 - survival_time_mae: 56.0082 - survival_time_root_mean_squared_error: 76.8536 - val_event_accuracy: 0.8617 - val_event_auc_9: 0.5730 - val_event_loss: 0.4006 - val_loss: 3656.8660 - val_survival_time_loss: 6223.3892 - val_survival_time_mae: 53.4199 - val_survival_time_root_mean_squared_error: 78.0673 - learning_rate: 5.0000e-04
# Epoch 93/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - event_accuracy: 0.8698 - event_auc_9: 0.5074 - event_loss: 0.4087 - loss: 3400.7378 - survival_time_loss: 5667.7593 - survival_time_mae: 55.4289 - survival_time_root_mean_squared_error: 75.1248 - val_event_accuracy: 0.8617 - val_event_auc_9: 0.5912 - val_event_loss: 0.3963 - val_loss: 3544.4155 - val_survival_time_loss: 6020.4414 - val_survival_time_mae: 52.5782 - val_survival_time_root_mean_squared_error: 76.8576 - learning_rate: 5.0000e-04
# Epoch 94/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - event_accuracy: 0.8698 - event_auc_9: 0.5647 - event_loss: 0.3952 - loss: 3390.1716 - survival_time_loss: 5650.1748 - survival_time_mae: 55.0239 - survival_time_root_mean_squared_error: 75.0056 - val_event_accuracy: 0.8617 - val_event_auc_9: 0.5892 - val_event_loss: 0.3955 - val_loss: 3495.5066 - val_survival_time_loss: 5948.3262 - val_survival_time_mae: 52.1290 - val_survival_time_root_mean_squared_error: 76.3255 - learning_rate: 5.0000e-04
# Epoch 95/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - event_accuracy: 0.8698 - event_auc_9: 0.5263 - event_loss: 0.4003 - loss: 3268.9011 - survival_time_loss: 5448.0649 - survival_time_mae: 53.7579 - survival_time_root_mean_squared_error: 73.5822 - val_event_accuracy: 0.8617 - val_event_auc_9: 0.5798 - val_event_loss: 0.3962 - val_loss: 3554.5530 - val_survival_time_loss: 6039.9375 - val_survival_time_mae: 52.7166 - val_survival_time_root_mean_squared_error: 76.9675 - learning_rate: 5.0000e-04
# Epoch 96/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - event_accuracy: 0.8698 - event_auc_9: 0.5062 - event_loss: 0.4070 - loss: 3399.3230 - survival_time_loss: 5665.4238 - survival_time_mae: 54.1248 - survival_time_root_mean_squared_error: 75.1028 - val_event_accuracy: 0.8617 - val_event_auc_9: 0.5822 - val_event_loss: 0.3978 - val_loss: 3466.2039 - val_survival_time_loss: 5893.1953 - val_survival_time_mae: 52.3189 - val_survival_time_root_mean_squared_error: 76.0049 - learning_rate: 5.0000e-04
# Epoch 97/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - event_accuracy: 0.8679 - event_auc_9: 0.5234 - event_loss: 0.4061 - loss: 3340.7163 - survival_time_loss: 5567.7080 - survival_time_mae: 54.4005 - survival_time_root_mean_squared_error: 74.3896 - val_event_accuracy: 0.8617 - val_event_auc_9: 0.5895 - val_event_loss: 0.3967 - val_loss: 3546.9282 - val_survival_time_loss: 6034.4868 - val_survival_time_mae: 52.8306 - val_survival_time_root_mean_squared_error: 76.8849 - learning_rate: 5.0000e-04
# Epoch 98/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - event_accuracy: 0.8663 - event_auc_9: 0.5281 - event_loss: 0.4050 - loss: 3258.6875 - survival_time_loss: 5431.0195 - survival_time_mae: 53.3238 - survival_time_root_mean_squared_error: 73.4860 - val_event_accuracy: 0.8617 - val_event_auc_9: 0.5932 - val_event_loss: 0.3956 - val_loss: 3605.9966 - val_survival_time_loss: 6139.0898 - val_survival_time_mae: 52.8746 - val_survival_time_root_mean_squared_error: 77.5224 - learning_rate: 5.0000e-04
# Epoch 99/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - event_accuracy: 0.8694 - event_auc_9: 0.5351 - event_loss: 0.4004 - loss: 3321.2559 - survival_time_loss: 5535.2793 - survival_time_mae: 54.0387 - survival_time_root_mean_squared_error: 74.1086 - val_event_accuracy: 0.8617 - val_event_auc_9: 0.5954 - val_event_loss: 0.3942 - val_loss: 3607.7224 - val_survival_time_loss: 6155.9155 - val_survival_time_mae: 53.1179 - val_survival_time_root_mean_squared_error: 77.5410 - learning_rate: 5.0000e-04
# Epoch 100/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - event_accuracy: 0.8698 - event_auc_9: 0.5103 - event_loss: 0.4055 - loss: 3272.3584 - survival_time_loss: 5453.7959 - survival_time_mae: 53.8934 - survival_time_root_mean_squared_error: 73.7064 - val_event_accuracy: 0.8617 - val_event_auc_9: 0.5828 - val_event_loss: 0.3978 - val_loss: 3654.7102 - val_survival_time_loss: 6210.6030 - val_survival_time_mae: 53.3205 - val_survival_time_root_mean_squared_error: 78.0443 - learning_rate: 5.0000e-04
# Epoch 101/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - event_accuracy: 0.8698 - event_auc_9: 0.5077 - event_loss: 0.4059 - loss: 3179.5601 - survival_time_loss: 5299.1372 - survival_time_mae: 52.3204 - survival_time_root_mean_squared_error: 72.5597 - val_event_accuracy: 0.8617 - val_event_auc_9: 0.5940 - val_event_loss: 0.3935 - val_loss: 3530.3254 - val_survival_time_loss: 6001.7817 - val_survival_time_mae: 53.2342 - val_survival_time_root_mean_squared_error: 76.7047 - learning_rate: 5.0000e-04
# Epoch 102/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - event_accuracy: 0.8698 - event_auc_9: 0.5346 - event_loss: 0.4006 - loss: 3314.7241 - survival_time_loss: 5524.4399 - survival_time_mae: 54.1786 - survival_time_root_mean_squared_error: 74.1890 - val_event_accuracy: 0.8617 - val_event_auc_9: 0.5900 - val_event_loss: 0.3968 - val_loss: 3577.2383 - val_survival_time_loss: 6097.0015 - val_survival_time_mae: 52.4416 - val_survival_time_root_mean_squared_error: 77.2127 - learning_rate: 5.0000e-04
# Epoch 103/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - event_accuracy: 0.8693 - event_auc_9: 0.5202 - event_loss: 0.4019 - loss: 3271.5710 - survival_time_loss: 5452.4712 - survival_time_mae: 53.1881 - survival_time_root_mean_squared_error: 73.6437 - val_event_accuracy: 0.8617 - val_event_auc_9: 0.5733 - val_event_loss: 0.3984 - val_loss: 3442.0366 - val_survival_time_loss: 5843.7871 - val_survival_time_mae: 52.2561 - val_survival_time_root_mean_squared_error: 75.7394 - learning_rate: 5.0000e-04
# Epoch 104/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - event_accuracy: 0.8698 - event_auc_9: 0.5025 - event_loss: 0.4056 - loss: 3198.6414 - survival_time_loss: 5330.9673 - survival_time_mae: 53.4642 - survival_time_root_mean_squared_error: 72.8435 - val_event_accuracy: 0.8617 - val_event_auc_9: 0.5905 - val_event_loss: 0.3961 - val_loss: 3508.5129 - val_survival_time_loss: 5965.5469 - val_survival_time_mae: 52.3304 - val_survival_time_root_mean_squared_error: 76.4674 - learning_rate: 5.0000e-04
# Epoch 105/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - event_accuracy: 0.8698 - event_auc_9: 0.4987 - event_loss: 0.4076 - loss: 3237.8757 - survival_time_loss: 5396.3457 - survival_time_mae: 53.9022 - survival_time_root_mean_squared_error: 73.3532 - val_event_accuracy: 0.8617 - val_event_auc_9: 0.5897 - val_event_loss: 0.3969 - val_loss: 3490.6501 - val_survival_time_loss: 5934.9727 - val_survival_time_mae: 52.2883 - val_survival_time_root_mean_squared_error: 76.2724 - learning_rate: 5.0000e-04
# Epoch 106/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - event_accuracy: 0.8694 - event_auc_9: 0.5023 - event_loss: 0.4070 - loss: 3268.5876 - survival_time_loss: 5447.5049 - survival_time_mae: 53.2937 - survival_time_root_mean_squared_error: 73.6690 - val_event_accuracy: 0.8617 - val_event_auc_9: 0.5886 - val_event_loss: 0.3968 - val_loss: 3583.4072 - val_survival_time_loss: 6091.3638 - val_survival_time_mae: 52.8224 - val_survival_time_root_mean_squared_error: 77.2792 - learning_rate: 5.0000e-04
# Epoch 107/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - event_accuracy: 0.8698 - event_auc_9: 0.5435 - event_loss: 0.3987 - loss: 3220.2661 - survival_time_loss: 5366.9995 - survival_time_mae: 53.2811 - survival_time_root_mean_squared_error: 73.1658 - val_event_accuracy: 0.8617 - val_event_auc_9: 0.5748 - val_event_loss: 0.4000 - val_loss: 3530.0425 - val_survival_time_loss: 6005.2847 - val_survival_time_mae: 52.1592 - val_survival_time_root_mean_squared_error: 76.7016 - learning_rate: 5.0000e-04
# Epoch 108/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - event_accuracy: 0.8681 - event_auc_9: 0.5248 - event_loss: 0.4023 - loss: 3259.9622 - survival_time_loss: 5433.1177 - survival_time_mae: 53.9132 - survival_time_root_mean_squared_error: 73.4924 - val_event_accuracy: 0.8617 - val_event_auc_9: 0.5912 - val_event_loss: 0.3960 - val_loss: 3548.7034 - val_survival_time_loss: 6026.7085 - val_survival_time_mae: 52.3874 - val_survival_time_root_mean_squared_error: 76.9041 - learning_rate: 5.0000e-04
# Epoch 109/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - event_accuracy: 0.8698 - event_auc_9: 0.5334 - event_loss: 0.4010 - loss: 3098.4004 - survival_time_loss: 5163.8662 - survival_time_mae: 52.4965 - survival_time_root_mean_squared_error: 71.6425 - val_event_accuracy: 0.8617 - val_event_auc_9: 0.5861 - val_event_loss: 0.3973 - val_loss: 3533.9788 - val_survival_time_loss: 6011.6714 - val_survival_time_mae: 52.1431 - val_survival_time_root_mean_squared_error: 76.7444 - learning_rate: 5.0000e-04
# Epoch 110/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - event_accuracy: 0.8698 - event_auc_9: 0.5224 - event_loss: 0.4028 - loss: 3324.6389 - survival_time_loss: 5540.9141 - survival_time_mae: 54.1569 - survival_time_root_mean_squared_error: 74.2215 - val_event_accuracy: 0.8617 - val_event_auc_9: 0.6049 - val_event_loss: 0.3923 - val_loss: 3430.7705 - val_survival_time_loss: 5824.6743 - val_survival_time_mae: 51.8742 - val_survival_time_root_mean_squared_error: 75.6154 - learning_rate: 5.0000e-04
# Epoch 111/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - event_accuracy: 0.8634 - event_auc_9: 0.5252 - event_loss: 0.4059 - loss: 3285.8376 - survival_time_loss: 5476.2588 - survival_time_mae: 53.6564 - survival_time_root_mean_squared_error: 73.8703 - val_event_accuracy: 0.8617 - val_event_auc_9: 0.6103 - val_event_loss: 0.3901 - val_loss: 3440.8494 - val_survival_time_loss: 5833.4160 - val_survival_time_mae: 51.7845 - val_survival_time_root_mean_squared_error: 75.7264 - learning_rate: 5.0000e-04
# Epoch 112/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - event_accuracy: 0.8698 - event_auc_9: 0.5246 - event_loss: 0.4028 - loss: 3251.9080 - survival_time_loss: 5419.6816 - survival_time_mae: 54.1578 - survival_time_root_mean_squared_error: 73.5207 - val_event_accuracy: 0.8617 - val_event_auc_9: 0.6024 - val_event_loss: 0.3914 - val_loss: 3457.7397 - val_survival_time_loss: 5867.3501 - val_survival_time_mae: 52.3162 - val_survival_time_root_mean_squared_error: 75.9120 - learning_rate: 5.0000e-04
# Epoch 113/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - event_accuracy: 0.8698 - event_auc_9: 0.4738 - event_loss: 0.4137 - loss: 3222.6460 - survival_time_loss: 5370.9565 - survival_time_mae: 53.0769 - survival_time_root_mean_squared_error: 73.1199 - val_event_accuracy: 0.8617 - val_event_auc_9: 0.6108 - val_event_loss: 0.3907 - val_loss: 3484.1304 - val_survival_time_loss: 5914.6270 - val_survival_time_mae: 52.2430 - val_survival_time_root_mean_squared_error: 76.2012 - learning_rate: 5.0000e-04
# Epoch 114/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - event_accuracy: 0.8693 - event_auc_9: 0.5049 - event_loss: 0.4043 - loss: 3034.1938 - survival_time_loss: 5056.9189 - survival_time_mae: 50.9961 - survival_time_root_mean_squared_error: 70.9260 - val_event_accuracy: 0.8617 - val_event_auc_9: 0.6027 - val_event_loss: 0.3927 - val_loss: 3444.9861 - val_survival_time_loss: 5844.9399 - val_survival_time_mae: 51.7618 - val_survival_time_root_mean_squared_error: 75.7719 - learning_rate: 5.0000e-04
# Epoch 115/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - event_accuracy: 0.8698 - event_auc_9: 0.5294 - event_loss: 0.4007 - loss: 3266.0312 - survival_time_loss: 5443.2661 - survival_time_mae: 53.6329 - survival_time_root_mean_squared_error: 73.6670 - val_event_accuracy: 0.8617 - val_event_auc_9: 0.5938 - val_event_loss: 0.3943 - val_loss: 3492.9824 - val_survival_time_loss: 5953.7114 - val_survival_time_mae: 51.6543 - val_survival_time_root_mean_squared_error: 76.2979 - learning_rate: 5.0000e-04
# Epoch 116/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - event_accuracy: 0.8692 - event_auc_9: 0.5133 - event_loss: 0.4010 - loss: 3212.0190 - survival_time_loss: 5353.1870 - survival_time_mae: 53.1999 - survival_time_root_mean_squared_error: 73.0165 - val_event_accuracy: 0.8617 - val_event_auc_9: 0.5844 - val_event_loss: 0.3948 - val_loss: 3423.9221 - val_survival_time_loss: 5839.7017 - val_survival_time_mae: 51.6674 - val_survival_time_root_mean_squared_error: 75.5399 - learning_rate: 5.0000e-04
# Epoch 117/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - event_accuracy: 0.8673 - event_auc_9: 0.4950 - event_loss: 0.4063 - loss: 3050.3901 - survival_time_loss: 5083.8218 - survival_time_mae: 52.7293 - survival_time_root_mean_squared_error: 71.2220 - val_event_accuracy: 0.8617 - val_event_auc_9: 0.5792 - val_event_loss: 0.3968 - val_loss: 3539.8450 - val_survival_time_loss: 6019.5566 - val_survival_time_mae: 52.4367 - val_survival_time_root_mean_squared_error: 76.8080 - learning_rate: 5.0000e-04
# Epoch 118/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - event_accuracy: 0.8669 - event_auc_9: 0.5257 - event_loss: 0.4051 - loss: 3247.9326 - survival_time_loss: 5413.0537 - survival_time_mae: 53.7843 - survival_time_root_mean_squared_error: 73.4383 - val_event_accuracy: 0.8617 - val_event_auc_9: 0.6036 - val_event_loss: 0.3929 - val_loss: 3646.0818 - val_survival_time_loss: 6207.0571 - val_survival_time_mae: 52.6837 - val_survival_time_root_mean_squared_error: 77.9522 - learning_rate: 5.0000e-04
# Epoch 119/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - event_accuracy: 0.8697 - event_auc_9: 0.5298 - event_loss: 0.3994 - loss: 3123.6130 - survival_time_loss: 5205.8828 - survival_time_mae: 52.3125 - survival_time_root_mean_squared_error: 71.9712 - val_event_accuracy: 0.8617 - val_event_auc_9: 0.6084 - val_event_loss: 0.3905 - val_loss: 3544.4768 - val_survival_time_loss: 6015.1250 - val_survival_time_mae: 53.1125 - val_survival_time_root_mean_squared_error: 76.8583 - learning_rate: 5.0000e-04
# Epoch 120/120
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - event_accuracy: 0.8661 - event_auc_9: 0.5226 - event_loss: 0.4039 - loss: 2968.2380 - survival_time_loss: 4946.9292 - survival_time_mae: 51.4218 - survival_time_root_mean_squared_error: 70.0549 - val_event_accuracy: 0.8617 - val_event_auc_9: 0.6048 - val_event_loss: 0.3922 - val_loss: 3479.0173 - val_survival_time_loss: 5931.2637 - val_survival_time_mae: 51.7927 - val_survival_time_root_mean_squared_error: 76.1452 - learning_rate: 5.0000e-04
# ======================================================================
# MODEL EVALUATION
# ======================================================================
# Evaluating model...
#
# Evaluation Results:
# loss: 3653.3398
# compile_metrics: 6203.8091
# survival_time_loss: 0.4132
# event_loss: 0.8646
#
# Detailed Performance Metrics:
#
# Survival Time Prediction:
#   MSE: 6088.6300
#   MAE: 53.9162
#   RMSE: 78.0297
#
# Event Prediction:
#   Accuracy: 0.8646
#   AUC-ROC: 0.5434
# ======================================================================
# ADDITIONAL PLOTS
# ======================================================================
# ======================================================================
# PIPELINE COMPLETED SUCCESSFULLY!
# ======================================================================
